# %%
import nltk
import re
from sklearn.datasets import fetch_20newsgroups

# %%
twenty_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
twenty_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'))

# %%
print(twenty_train.data[0])
# Out:
# I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.

# %% [markdown]
# ## Задание 1

# %%
def preprocessing(twenty_train):
    

    for i in range(len(twenty_train.data)):
        lines = twenty_train.data[i].split('\n')
        
        
        #Перевод символов в нижний регистр
        lines = [line.lower() for line in lines]
    
    
        twenty_train.data[i] =  '\n'.join(lines)
        #Удаление символов, не являющихся буквами или цифрами

        updText = ""
        for j in range(len(twenty_train.data[i])):
            sym = twenty_train.data[i][j]
            if not sym.isalnum():
                if updText and updText[-1] != ' ':
                    updText = updText + ' '
            else:
                updText = updText + sym
                
        twenty_train.data[i] =  updText

# %%
preprocessing(twenty_train)
preprocessing(twenty_test)

# %%
print(twenty_train.data[0])
# Out:
# i was wondering if anyone out there could enlighten me on this car i saw the other day it was a 2 door sports car looked to be from the late 60s early 70s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please e mail

# %%
len(twenty_train.data)
# Out:
# 11314

# %% [markdown]
# # Задание 2

# %% [markdown]
# ## 2. CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn import metrics
from sklearn.svm import SVC
from sklearn import cross_validation
from random import randint
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# /home/pavel/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def CountVectorizerStats(train, test):
    count_vect = CountVectorizer()
    
    CV_train_counts = count_vect.fit_transform(train.data)
    CV_test_counts = count_vect.transform(test.data)
    CV_x_train, CV_x_test, CV_y_train, CV_y_test = cross_validation.train_test_split(CV_train_counts, twenty_train.target, 
                                                            test_size = 0.1, random_state = randint(0, 100))
    svm = SGDClassifier()
    svm.fit(CV_x_train, CV_y_train)
    CV_valid_predicted = svm.predict(CV_x_test)
    print(metrics.classification_report(CV_y_test, CV_valid_predicted,
                                    target_names=test.target_names))
    
    CVpredicted = svm.predict(CV_test_counts)
    return metrics.classification_report(test.target, CVpredicted,
                                    target_names=test.target_names), CVpredicted

# %% [markdown]
# ## 2. TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier

def TfIdfValidation(train, test):
    print(train.data[0])
    idf_vectorizer = TfidfVectorizer()
    
    x_train_counts = idf_vectorizer.fit_transform(train.data)
    x_test_counts = idf_vectorizer.transform(test.data)
    v_x_train, v_x_test, v_y_train, v_y_test = cross_validation.train_test_split(x_train_counts, train.target,  #twenty_train instead train
                                                            test_size = 0.1, random_state = randint(0, 100))
    svm = SGDClassifier()
    svm.fit(v_x_train, v_y_train)
    v_predicted = svm.predict(v_x_test)
    
    print(metrics.classification_report(v_y_test, v_predicted,
                                    target_names=test.target_names))
    

def TfIdf(train, test):
    idf_vectorizer = TfidfVectorizer()
    
    x_train_counts = idf_vectorizer.fit_transform(train.data)
    x_test_counts = idf_vectorizer.transform(test.data)
    
    svm = SGDClassifier()
    svm.fit(x_train_counts, train.target)
    predicted = svm.predict(x_test_counts)
    
    print(metrics.classification_report(test.target, predicted,
                                    target_names=test.target_names))
    return predicted, x_train_counts.shape

# %% [markdown]
# ## 2. Классификация на валидационной выборке:

# %% [markdown]
# ### 2. CountVectorizer

# %%
CVmetric, CVpredicted = CountVectorizerStats(twenty_train, twenty_test)
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.57      0.53      0.55        47
#            comp.graphics       0.75      0.17      0.28        69
#  comp.os.ms-windows.misc       0.45      0.58      0.51        59
# comp.sys.ibm.pc.hardware       0.48      0.46      0.47        61
#    comp.sys.mac.hardware       0.50      0.59      0.54        61
#           comp.windows.x       0.54      0.69      0.61        45
#             misc.forsale       0.47      0.68      0.56        57
#                rec.autos       0.68      0.70      0.69        66
#          rec.motorcycles       0.61      0.78      0.68        72
#       rec.sport.baseball       0.47      0.79      0.59        58
#         rec.sport.hockey       0.74      0.85      0.79        67
#                sci.crypt       0.52      0.80      0.63        56
#          sci.electronics       0.48      0.43      0.45        56
#                  sci.med       0.76      0.71      0.74        55
#                sci.space       0.81      0.67      0.74        52
#   soc.religion.christian       0.60      0.51      0.55        51
#       talk.politics.guns       0.00      0.00      0.00        59
#    talk.politics.mideast       0.56      0.63      0.59        60
#       talk.politics.misc       0.56      0.46      0.51        39
#       talk.religion.misc       0.32      0.14      0.20        42
#
#              avg / total       0.55      0.57      0.54      1132

# %% [markdown]
# ### 2. TfIdfVectorizer

# %%
TfIdfValidation(twenty_train, twenty_test)
# Out:
# i was wondering if anyone out there could enlighten me on this car i saw the other day it was a 2 door sports car looked to be from the late 60s early 70s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please e mail
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.57      0.58      0.57        43
#            comp.graphics       0.85      0.73      0.79        60
#  comp.os.ms-windows.misc       0.72      0.77      0.75        71
# comp.sys.ibm.pc.hardware       0.72      0.64      0.68        59
#    comp.sys.mac.hardware       0.70      0.71      0.70        45
#           comp.windows.x       0.80      0.83      0.81        53
#             misc.forsale       0.53      0.91      0.67        53
#                rec.autos       0.77      0.76      0.76        66
#          rec.motorcycles       0.82      0.77      0.79        64
#       rec.sport.baseball       0.81      0.88      0.84        58
#         rec.sport.hockey       0.89      0.92      0.90        61
#                sci.crypt       0.87      0.80      0.84        51
#          sci.electronics       0.74      0.66      0.70        59
#                  sci.med       0.79      0.90      0.84        59
#                sci.space       0.79      0.84      0.82        58
#   soc.religion.christian       0.79      0.84      0.82        63
#       talk.politics.guns       0.84      0.79      0.82        67
#    talk.politics.mideast       0.81      0.76      0.79        58
#       talk.politics.misc       0.89      0.58      0.70        53
#       talk.religion.misc       0.69      0.35      0.47        31
#
#              avg / total       0.77      0.77      0.76      1132

# %% [markdown]
# #### Как мы видим, преобразование датасета с помощью TfIdfVectorizer дает более качественную классификацию

# %% [markdown]
# ### 2. Классификация на тестовой выборке:

# %%
TFpredicted, shape = TfIdf(twenty_train, twenty_test)
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.51      0.46      0.48       319
#            comp.graphics       0.67      0.71      0.69       389
#  comp.os.ms-windows.misc       0.65      0.61      0.63       394
# comp.sys.ibm.pc.hardware       0.68      0.65      0.66       392
#    comp.sys.mac.hardware       0.78      0.70      0.73       385
#           comp.windows.x       0.80      0.72      0.76       395
#             misc.forsale       0.76      0.82      0.79       390
#                rec.autos       0.79      0.72      0.75       396
#          rec.motorcycles       0.51      0.80      0.62       398
#       rec.sport.baseball       0.83      0.81      0.82       397
#         rec.sport.hockey       0.88      0.89      0.88       399
#                sci.crypt       0.85      0.71      0.78       396
#          sci.electronics       0.62      0.56      0.59       393
#                  sci.med       0.82      0.76      0.79       396
#                sci.space       0.74      0.73      0.74       394
#   soc.religion.christian       0.58      0.84      0.69       398
#       talk.politics.guns       0.58      0.68      0.62       364
#    talk.politics.mideast       0.80      0.75      0.77       376
#       talk.politics.misc       0.51      0.50      0.51       310
#       talk.religion.misc       0.57      0.20      0.30       251
#
#              avg / total       0.70      0.70      0.69      7532

# %% [markdown]
# ### 2. Примеры текстов, на которых алгоритм ошибается

# %%
def printExample(twenty_test, TFpredicted, num):
    topics = twenty_test.target_names.copy()
    print("Predicted topic:", topics[TFpredicted[num]])
    print("Original topic:", topics[twenty_test.target[num]])
    print("TEXT:\n", twenty_test.data[num])
    print()

print("Example №1")
printExample(twenty_test, TFpredicted, 14)
print("Example №2")
printExample(twenty_test, TFpredicted, 15)
print("Example №3")
printExample(twenty_test, TFpredicted, 89)
print("Example №4")
printExample(twenty_test, TFpredicted, 98)
print("Example №5")
printExample(twenty_test, TFpredicted, 164)
print("Example №6")
printExample(twenty_test, TFpredicted, 205)
print("Example №7")
printExample(twenty_test, TFpredicted, 209)
print("Example №8")
printExample(twenty_test, TFpredicted, 219)
print("Example №9")
printExample(twenty_test, TFpredicted, 229)
print("Example №10")
printExample(twenty_test, TFpredicted, 207)
print("Example №11")
printExample(twenty_test, TFpredicted, 233)
print("Example №12")
printExample(twenty_test, TFpredicted, 227)
print("Example №13")
printExample(twenty_test, TFpredicted, 246)
print("Example №14")
printExample(twenty_test, TFpredicted, 254)
# Out:
# Example №1
# Predicted topic: soc.religion.christian
# Original topic: alt.atheism
# TEXT:
#  probably because it is rape so nothing it may work for some but not for others it doesn t give any insight into an overall god or overall truth of a religion it would seem to be dependent solely on the individual as well as individually created and since christians have failed to show us how there way of life is in any wy better than ours i do not see why the attempt to try it is necessary or even particularly attractive well we will nerver know for sure if we were told the truth or not but at the very least there is a bit more evidence pointing to the fact that say there was a military conflict in vietnam 25 years ago then there is a supernatural diety who wants us to live a certain way the fact that jesus warned against it means nothing i warn against it too big deal this is not true the first two choices here life and death are scantily documented and the last one is total malarky unless one uses the bible and that is totally circular perhaps it be better to use the imagination or one s ignorance someone else will address this i m sure and refer you to plenty of documentation how is this there is nothing more disgusting than christian attempts to manipulate interpret the old testament as being filled with signs for the coming of christ every little reference to a stick or bit of wood is autmoatically interpreted as the cross what a miscarriage of philology well since we have skeptical hearts thank goodness there is no way to get into us here we have the irreconcilable difference christians glorify exactly what we tend to despise or snub trust belief faith without knowledge if i am lucky one day and i happen to be thinking of god at the same time my enkephalins go up then i may associate this as a sign of god it will feel right and i will trust without knowing maybe religosity does not seem to be anything that is conclusively arrived at but rather it seems to be more of a sudden affliction i believe many of us were willing to die for what we believed many of us were not the question is is suchg an attitude reflective of a correct or healthy morality it would seem not to be the same thing could reflect fanaticism for example and is any case an expression of simple selfishness adam
#
# Example №2
# Predicted topic: comp.sys.ibm.pc.hardware
# Original topic: comp.os.ms-windows.misc
# TEXT:
#  from article c68ubg k2w world std com by cfw world std com christopher f wroten good question answer the eisa bus does move 32 bits rather than isa s 8 16 but it still moves it at about the speed as the isa bus i think that s either 8 or 10 mhz the local bus designs also move 32 bits like the eisa but they move the data at the cpu speed up to 40 mhz so on a 33mhz cpu the local bus is moving 32bit data at 33 mhz and the eisa is moving 32bit data at 8 or 10 mhz so the local bus should be 3 to 4 times faster than eisa on a 33 mhz cpu eisa should be about two maybe 3 times as fast as isa that s a very good question the eisa bus does have more advantages over the isa bus than just it s width for example more better interrupts and bus mastering but these other factors do not impact a video card very much they have more impact on file servers with multiple hard drives full throttle network cards cd roms etc
#
# Example №3
# Predicted topic: comp.sys.ibm.pc.hardware
# Original topic: comp.sys.mac.hardware
# TEXT:
#  hey all we have an old 1990 external hd attached to the plus in our lab it had given us flawless service until last week the problem someone in our lab has an old 512 that was upgraded a couple years ago to a plus with an aftermarket simm scsi setup digigraphics simmer the db25 scsi plug runs through the back of the machine and attaches to the board with a 26 pin rectangular connector well this guy had removed the back from the machine to put more memory in and had disconnected the the scsi plug since the 26 pin connector is symmetrical not keyed he may have reinstalled it upside down essentially reversing the pins on the db25 he came in and asked if he could try out our hd on his scsi port it had never been used naive fools that we are we said o k his computer failed to recognize the drive now none of the computers in our lab will recognize it we tried disk doctor and it doesn t recognize anything on the scsi chain could installing the scsi upside down have wrecked the hd s driver board the drive seems to spin up all right and unpark itself upon powerup the events are too coincidental to attribute the problem to stiction any help greatly appreciated
#
# Example №4
# Predicted topic: comp.os.ms-windows.misc
# Original topic: comp.sys.ibm.pc.hardware
# TEXT:
#  i am servicing a machine hp 286 and whenever the thing starts up i get 4 beeps on powerup does anyone know what error message that signifies i don t seem to have any problem with the machine but the lady who is using it is very concerned about it don t you just love hp computers preferr responses by e mail but i read the net so you can post it here
#
# Example №5
# Predicted topic: sci.electronics
# Original topic: comp.sys.ibm.pc.hardware
# TEXT:
#  what tube does the viewsonic 17 use does is support 1600x1280 i ve been looking a a philips 1762dt which uses a sony trinitron tube has digital controls supports up to 1280x1024ni and has 25mm dot pitch it can be found for under 1000 the original poster john navitsky said that he might use the monitor on a sparcstation lx the lx is able to generate a picture at 1280 1024 at 76 hz not officially but i tried to set this resolution and refresh rate and the lx came up with a non syncing screen our tube obviously couldn t handle this speed at 67 hz it worked perfectly i don t know which tube the viewsonic 17 uses but it has an 82khz horizontal bandwidth so you can go pretty high i ran mine at 1280x1024x75 which was as fast as the orchid p9000 could drive it also the 17 does claim to be able to support 1600x1280 but i have no experience with that since i have the spec sheet in front of me i ll type some in crt 17 0 28 mm dot pitch 90 deg deflection rgb mediou short persisance tint tm 52 anti static anti glare anti reflection input signal rgb analog 0 7vp p 75 ohms also has setting for 1vp p sync h v separate ttl composite sync on green horizontal freq 30 82khz vertical freq 50 90hz compatibility pc from vga to 1600x1280 non interlaced mac iici and above controls contrast brightness position size degauss p p voltage color temp sync select color tuning moire on off video band witdth 135 mhz max brightness 120 cd m2 at white flat field misconvergence 35mm max at center 45mm max at corner dimensions 16 3 x16 22 x17 64 weight 42 6 lbs i don t know what some of those mean and don t verify their accuracy i just typed them in other things they hype on the sheet are a double quaduple dynamic astigmatism focus right they mean they use two lenses advanced invar shadow mask viewmatch color control which they claim is and easy to use system that adjusts colors to closely match printer output as near as i have been able to figure out this translates to separate controls for red green and blue how this makes it easy to match for printer output is beyond me but beyond the hype the monitor is very pleasant to look at sharp clear and isn t nearly as bad as the nec s for reflections
#
# Example №6
# Predicted topic: comp.windows.x
# Original topic: sci.electronics
# TEXT:
#  is there a readily available solvent that does a good job at removing the corrosion encrustation that collects on the battery terminals usually the cathode when using alkaline batteries or more accurately when not using them for a long time
#
# Example №7
# Predicted topic: talk.religion.misc
# Original topic: soc.religion.christian
# TEXT:
#  but whoso hearkeneth unto me shall dwell safely and shall be quiet from fear of evil
#
# Example №8
# Predicted topic: soc.religion.christian
# Original topic: alt.atheism
# TEXT:
#  stuff deleted as many posters have said in as many posts lately this is just not true for to show no interest in the existence of god takes no faith at all you make the presumption that the knowledge of the possibility of something is enough to require faith to render that possibilty of no interest it is a very different thing to say that you don t believe something than it is to say that you don t have sufficent reason to believe something is even interesting to think about it s not either or sometimes is just something else more interesting that occupies your mind i agree that faith and dogma are inevitable but not necessarily applied to god and religion it takes both faith and dogma to expect the sun to come up every morning but there is overwhelming reason every single day day in and day out for everyone to put his faith and dogma there not so with the christian religion
#
# Example №9
# Predicted topic: sci.electronics
# Original topic: rec.autos
# TEXT:
#  it seems that there are more and more bands available for police radar each month i have recently purchased within the last 8 months the bel 966stw while it is not a perfect detector by any means it does do the job fairly well now however i pick up a car magazine at the airport and read about this super ka wideband which is a superset of the ka wideband that this latest generation of detectors was touted as covering so now bel has a new series of detectors out that cover all the usual bands x k ka photo ka wideband as well as the new super ka wideband just as there comes a point of diminishing returns when chasing increased pc computing power with faster and faster cpus for the average home consumer at least it seems that there is now the same concern with radar detectors does it make sense to upgrade just 8 months after purchasing my new detector is valentine upgrading their equipment if so it might be worth it for me to upgrade to the valentine i was in the market for a valentine when i purchased the bel but the 3 4 month waiting time was just too much for me since i had inadequate protection with my passport life was much simpler when there was just x and k band and escort has the best equipment on the market and there was no need to continuously shop for a new detector i hope that the flood of new radar bands ceases with this new super wideband business
#
# Example №10
# Predicted topic: sci.space
# Original topic: comp.graphics
# TEXT:
#  i worked in support for a while at a company and we had problems with several toshiba 1600 s in a short space of time they were all around 2 years old some screens went completely as above others were just dodgy this happened to about 5 or 6 out of maybe 100 they were fairly reliable up to then and i don t think it was a special problem with tosh s no link to the company so i would think that 21 months may not be unreasonable just unlucky regards kate
#
# Example №11
# Predicted topic: rec.motorcycles
# Original topic: talk.politics.mideast
# TEXT:
#  what say you and nick go somewhere else with this shool yard crap
#
# Example №12
# Predicted topic: talk.politics.guns
# Original topic: comp.os.ms-windows.misc
# TEXT:
#  much bs deleted for brevity it certainly smacks of that remember the poll that you quoted saying that you had seen a 95 of users being satisfied with dos 6 0 care to recall how unbiased the sample set was that post sure looked like fud and coming from a microsoftie well it sure seemed like something was not on level advocacy is good but spreading fud to advocate your favorite os is very unethical especially when you have a vested interest in the success of that os that is because their actions seem to invite this opinion never seen more defensive people in my life moreover many of their posts seem to encourage this too imho seriously speaking it is a shame that ms techie employees get the heat for ms s actions most of which are perpetrated by the management and marketing i am sure that they are very talented etc i have not doubts about their abilities just about the ethics of their marketing practices divya divya
#
# Example №13
# Predicted topic: alt.atheism
# Original topic: sci.space
# TEXT:
#  heck some of his ships were loaners one was owned by a basque you know one of those groups that probably crossed the atlantic before columbus came along
#
# Example №14
# Predicted topic: alt.atheism
# Original topic: misc.forsale
# TEXT:
#  i just wanted to let you know that there are a few honest and good people out there even outside of iowa i m sorry if anyone thinks that i am wasting space but i thought you might want some relief from the so and so is a thief posts not that i think we shouldn t hear about the bad deals but it would be nice to hear some good news once in a while this was nice of kevin to post this but just so no one is misled the vast majority of usenetters are honest and good people in fact in the latest study 99 7 of all net deals went off smoothly without a hitch it s just that the few bad ones are what get all the publicity agreed i have yet to run into a problem in deals over the net and i have bought things from cds plenty to a full computer the only small problem that i have had was with ups rather than the seller besides complaints are always what get the publicity when something goes wrong people complain rarely have i seen posts stating how well a deal went through i guess kevin is practically a first

# %% [markdown]
# #### Анализ:
# Как мы видим, алгоритм может перепутать тексты, как схожие по тематике (примеры 1 - 10), так и абсолютно различные (примеры 11-14), при этом на последних примерах можно заметить, что точность классификации ухудшается при уменьшении размера текста, что, вообще говоря, логично

# %% [markdown]
# ### 2. Матрица ошибок для TF-IDF:

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

np.set_printoptions(precision=2)

# %%
cnf_matrix = metrics.confusion_matrix(twenty_test.target, TFpredicted)
plt.figure(figsize = (20, 10))
plot_confusion_matrix(cnf_matrix, classes=twenty_train.target_names,
                      title='Confusion matrix, without normalization')

plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# #### Анализ:
# Как мы видим, больше всего алгоритм допускает ошибок в нечетко-заданных темах (misc).
# Например, следующие темы:
# (talk.religion.misc, soc.religion.christian),
# (talk.politics.misc, talk.politics.guns),
# (comp.ps.ms-windows.misc, comp.sys.ibm.pc.hardware)
#
# Также достаточно плохо классифицируется misc.forsale
#
# В целом же, алгоритм в основном правльно классифицирует тексты и редко абсолютно неверно угадывает тему текста.

# %% [markdown]
# ## Задание 3

# %%
original_train_texts = twenty_train.data.copy()
original_test_texts = twenty_test.data.copy()

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language='english')
stemming_train_texts = [' '.join([stemmer.stem(word) for word in text.split()]) for text in original_train_texts]
stemming_test_texts = [' '.join([stemmer.stem(word) for word in text.split()]) for text in original_test_texts]

# %%
print(twenty_train.data[1])
print()
print(stemming_train_texts[1])
# Out:
# a fair number of brave souls who upgraded their si clock oscillator have shared their experiences for this poll please send a brief message detailing your experiences with the procedure top speed attained cpu rated speed add on cards and adapters heat sinks hour of usage per day floppy disk functionality with 800 and 1 4 m floppies are especially requested i will be summarizing in the next two days so please add to the network knowledge base if you have done the clock upgrade and haven t answered this poll thanks
#
# a fair number of brave soul who upgrad their si clock oscil have share their experi for this poll pleas send a brief messag detail your experi with the procedur top speed attain cpu rate speed add on card and adapt heat sink hour of usag per day floppi disk function with 800 and 1 4 m floppi are especi request i will be summar in the next two day so pleas add to the network knowledg base if you have done the clock upgrad and haven t answer this poll thank

# %%
from nltk import wordnet, pos_tag
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk import WordNetLemmatizer
def get_wordnet_pos(treebank_tag):
    my_switch = {
        'J': wordnet.wordnet.ADJ,
        'V': wordnet.wordnet.VERB,
        'N': wordnet.wordnet.NOUN,
        'R': wordnet.wordnet.ADV,
    }
    for key, item in my_switch.items():
        if treebank_tag.startswith(key):
            return item
    return wordnet.wordnet.NOUN
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/pavel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/pavel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def my_lemmatizer(sent):
    lemmatizer = WordNetLemmatizer()
    tokenized_sent = sent.split()
    pos_tagged = [(word, get_wordnet_pos(tag))
                 for word, tag in pos_tag(tokenized_sent)]
    return ' '.join([lemmatizer.lemmatize(word, tag)
                    for word, tag in pos_tagged])

lemmatization_train_texts = [my_lemmatizer(text) for text in original_train_texts]
lemmatization_test_texts = [my_lemmatizer(text) for text in original_test_texts]

# %%
print(lemmatization_train_texts[0])
print()
print(twenty_train.data[0])
# Out:
# i be wonder if anyone out there could enlighten me on this car i saw the other day it be a 2 door sport car look to be from the late 60 early 70 it be call a bricklin the door be really small in addition the front bumper be separate from the rest of the body this be all i know if anyone can tellme a model name engine spec year of production where this car be make history or whatever info you have on this funky look car please e mail
#
# i was wondering if anyone out there could enlighten me on this car i saw the other day it was a 2 door sports car looked to be from the late 60s early 70s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please e mail

# %%
def stemming_texts(train, test):
    train.data = [' '.join([stemmer.stem(word) for word in text.split()]) for text in train.data]
    test.data = [' '.join([stemmer.stem(word) for word in text.split()]) for text in test.data]
    
def lemmatization_texts(train, test):
    train.data = [my_lemmatizer(text) for text in train.data]
    test.data = [my_lemmatizer(text) for text in test.data]
    
def original_texts(train, test, origTrain, originTest):
    train.data = origTrain.copy()
    test.data = originTest.copy()

# %% [markdown]
# ### 3. Классификация без предобработки

# %%
prediction, shape = TfIdf(twenty_train, twenty_test)
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.54      0.48      0.51       319
#            comp.graphics       0.68      0.72      0.70       389
#  comp.os.ms-windows.misc       0.66      0.62      0.64       394
# comp.sys.ibm.pc.hardware       0.68      0.65      0.66       392
#    comp.sys.mac.hardware       0.76      0.71      0.73       385
#           comp.windows.x       0.76      0.73      0.74       395
#             misc.forsale       0.51      0.84      0.63       390
#                rec.autos       0.79      0.71      0.75       396
#          rec.motorcycles       0.81      0.77      0.79       398
#       rec.sport.baseball       0.87      0.79      0.83       397
#         rec.sport.hockey       0.84      0.89      0.87       399
#                sci.crypt       0.86      0.71      0.78       396
#          sci.electronics       0.63      0.58      0.60       393
#                  sci.med       0.77      0.78      0.77       396
#                sci.space       0.73      0.75      0.74       394
#   soc.religion.christian       0.61      0.83      0.70       398
#       talk.politics.guns       0.58      0.70      0.63       364
#    talk.politics.mideast       0.79      0.77      0.78       376
#       talk.politics.misc       0.57      0.47      0.52       310
#       talk.religion.misc       0.51      0.20      0.29       251
#
#              avg / total       0.70      0.70      0.69      7532

# %% [markdown]
# ### 3. Классификация после стемминга:

# %%
twenty_train.data = stemming_train_texts.copy()
twenty_test.data = stemming_test_texts.copy()
stemPrediction,stemShape = TfIdf(twenty_train, twenty_test)
twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.55      0.51      0.53       319
#            comp.graphics       0.64      0.74      0.69       389
#  comp.os.ms-windows.misc       0.63      0.57      0.60       394
# comp.sys.ibm.pc.hardware       0.70      0.64      0.67       392
#    comp.sys.mac.hardware       0.70      0.73      0.72       385
#           comp.windows.x       0.83      0.69      0.75       395
#             misc.forsale       0.75      0.82      0.79       390
#                rec.autos       0.82      0.70      0.75       396
#          rec.motorcycles       0.79      0.74      0.77       398
#       rec.sport.baseball       0.55      0.87      0.68       397
#         rec.sport.hockey       0.86      0.91      0.89       399
#                sci.crypt       0.81      0.73      0.77       396
#          sci.electronics       0.58      0.57      0.57       393
#                  sci.med       0.82      0.77      0.79       396
#                sci.space       0.71      0.75      0.73       394
#   soc.religion.christian       0.68      0.79      0.73       398
#       talk.politics.guns       0.57      0.70      0.63       364
#    talk.politics.mideast       0.79      0.77      0.78       376
#       talk.politics.misc       0.59      0.45      0.51       310
#       talk.religion.misc       0.48      0.24      0.32       251
#
#              avg / total       0.70      0.70      0.69      7532

# %% [markdown]
# ### 3. Классификация после лемматизации

# %%
twenty_train.data = lemmatization_train_texts.copy()
twenty_test.data = lemmatization_test_texts.copy()
lemPrediction, lemShape = TfIdf(twenty_train, twenty_test)
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.52      0.48      0.50       319
#            comp.graphics       0.71      0.72      0.72       389
#  comp.os.ms-windows.misc       0.61      0.59      0.60       394
# comp.sys.ibm.pc.hardware       0.67      0.66      0.66       392
#    comp.sys.mac.hardware       0.69      0.73      0.71       385
#           comp.windows.x       0.80      0.72      0.76       395
#             misc.forsale       0.75      0.81      0.77       390
#                rec.autos       0.79      0.71      0.75       396
#          rec.motorcycles       0.81      0.74      0.77       398
#       rec.sport.baseball       0.56      0.84      0.67       397
#         rec.sport.hockey       0.84      0.91      0.87       399
#                sci.crypt       0.86      0.71      0.78       396
#          sci.electronics       0.62      0.55      0.59       393
#                  sci.med       0.76      0.80      0.78       396
#                sci.space       0.73      0.75      0.74       394
#   soc.religion.christian       0.64      0.82      0.72       398
#       talk.politics.guns       0.57      0.68      0.62       364
#    talk.politics.mideast       0.83      0.76      0.80       376
#       talk.politics.misc       0.57      0.46      0.51       310
#       talk.religion.misc       0.48      0.23      0.31       251
#
#              avg / total       0.70      0.70      0.69      7532

# %% [markdown]
# #### Как мы видим, предобработка корпуса не повлияла на точность классификации

# %% [markdown]
# ### 3. Время работы

# %%
import time
def countTime(train, test, experimentsNum):
    ansTime = 0
    idf_vectorizer = TfidfVectorizer()
    for i in range(experimentsNum):
        curTime = time.clock()
    
        x_train_counts = idf_vectorizer.fit_transform(train.data)
        x_test_counts = idf_vectorizer.transform(test.data)
    
        svm = SGDClassifier()
        svm.fit(x_train_counts, train.target)
        predicted = svm.predict(x_test_counts)
        ansTime += time.clock() - curTime
    ansTime = ansTime/experimentsNum
    return ansTime

twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()
print("Time without сorpus preprocessing:", countTime(twenty_train, twenty_test, 10))

twenty_train.data = stemming_train_texts.copy()
twenty_test.data = stemming_test_texts.copy()
print("Time after stemming:", countTime(twenty_train, twenty_test, 10))

twenty_train.data = lemmatization_train_texts.copy()
twenty_test.data = lemmatization_test_texts.copy()
print("Time after lemmatization:", countTime(twenty_train, twenty_test, 10))
twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()
# Out:
# Time without сorpus preprocessing: 5.150761700000004
# Time after stemming: 4.614668799999999
# Time after lemmatization: 4.7499326000000055

# %% [markdown]
# ### 3. Изменение размерности признакового пространства:

# %%
print("Original dimension:", shape[1])
print("Dimension after stemming :", stemShape[1])
print("Dimension after lemmatization:", lemShape[1])
# Out:
# Original dimension: 98706
# Dimension after stemming : 81491
# Dimension after lemmatization: 90718

# %% [markdown]
# # Задание 4

# %%
twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()
print(twenty_train.data[0])
# Out:
# i was wondering if anyone out there could enlighten me on this car i saw the other day it was a 2 door sports car looked to be from the late 60s early 70s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please e mail

# %% [markdown]
# ## 4. Удаление самых редких и самых частых слов

# %%
import collections
wordCount = {}
for text in original_train_texts:
    for word in text.split():
        if word in wordCount:
            wordCount[word] += 1
        else:
            wordCount[word] = 1

word_counter = collections.Counter(wordCount)
sortedWordCount = word_counter.most_common()
sortedWords = [pair[0] for pair in sortedWordCount]
forbiddenWords = set()

# %%
def update_forbidden_words(forbiddenWords,num1, num2):
    forbiddenWords.clear()
    for i in range(num1):
        forbiddenWords.add(sortedWords[i])
    for i in range(num2):
         forbiddenWords.add(sortedWords[len(sortedWords) - i - 1])

# %%
def update_texts(train, test, forbiddenWords):
    for i in range(len(train.data)):
        words = train.data[i].split()
        wordNum = 0
        while wordNum < (len(words)):
            if words[wordNum] in forbiddenWords:
                del words[wordNum]
                wordNum -= 1
            wordNum += 1
        train.data[i] = ' '.join(words)
    for i in range(len(test.data)):
        words = test.data[i].split()
        wordNum = 0
        while wordNum < (len(words)):
            if words[wordNum] in forbiddenWords:
                del words[wordNum]
                wordNum -= 1
            wordNum += 1
        test.data[i] = ' '.join(words)

# %%
def deleteWordsStats(twenty_train, twenty_test, forbiddenWords):
    original_train_texts = twenty_train.data.copy()
    original_test_texts = twenty_test.data.copy()
    update_texts(twenty_train, twenty_test, forbiddenWords)
    TfIdf(twenty_train, twenty_test)
    twenty_train.data = original_train_texts.copy()
    twenty_test.data = original_test_texts.copy()

# %% [markdown]
# ## 4. Без предобработки

# %%
original_texts(twenty_train, twenty_test, original_train_texts, original_test_texts)
twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()

# %%
deletions = [(0, 0), (0, 10000), (0, 25000), (0, 40000), (0, 55000), (0, 70000), (0, 85000), (0, 90000), (10000, 0), (25000, 0), (40000, 0), (55000, 0), (70000, 0), (85000, 0), (90000, 0), (10000, 10000), (20000, 20000), (30000, 30000), (40000, 40000)]

# %%
for el in deletions:
    print("Most frequent words deleted -", el[0])
    print("Least frequent words deleted -", el[1])
    update_forbidden_words(forbiddenWords, el[0], el[1])
    print("RESULTS:")
    deleteWordsStats(twenty_train, twenty_test, forbiddenWords)
    print("Time without сorpus preprocessing:", countTime(twenty_train, twenty_test, 1))
    print()
# Out:
# Most frequent words deleted - 0
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.51      0.47      0.49       319
#            comp.graphics       0.67      0.72      0.69       389
#  comp.os.ms-windows.misc       0.61      0.62      0.62       394
# comp.sys.ibm.pc.hardware       0.67      0.65      0.66       392
#    comp.sys.mac.hardware       0.77      0.69      0.73       385
#           comp.windows.x       0.81      0.71      0.76       395
#             misc.forsale       0.77      0.81      0.79       390
#                rec.autos       0.82      0.70      0.76       396
#          rec.motorcycles       0.79      0.79      0.79       398
#       rec.sport.baseball       0.55      0.84      0.66       397
#         rec.sport.hockey       0.83      0.89      0.86       399
#                sci.crypt       0.81      0.73      0.76       396
#          sci.electronics       0.64      0.55      0.59       393
#                  sci.med       0.77      0.79      0.78       396
#                sci.space       0.74      0.74      0.74       394
#   soc.religion.christian       0.66      0.81      0.73       398
#       talk.politics.guns       0.58      0.69      0.63       364
#    talk.politics.mideast       0.80      0.77      0.78       376
#       talk.politics.misc       0.58      0.46      0.52       310
#       talk.religion.misc       0.46      0.26      0.33       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time without сorpus preprocessing: 4.6055580000000305
#
# Most frequent words deleted - 0
# Least frequent words deleted - 10000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.50      0.47      0.48       319
#            comp.graphics       0.67      0.71      0.69       389
#  comp.os.ms-windows.misc       0.64      0.61      0.62       394
# comp.sys.ibm.pc.hardware       0.65      0.67      0.66       392
#    comp.sys.mac.hardware       0.76      0.70      0.73       385
#           comp.windows.x       0.84      0.71      0.77       395
#             misc.forsale       0.77      0.81      0.79       390
#                rec.autos       0.77      0.71      0.74       396
#          rec.motorcycles       0.79      0.76      0.77       398
#       rec.sport.baseball       0.55      0.82      0.66       397
#         rec.sport.hockey       0.83      0.89      0.86       399
#                sci.crypt       0.85      0.71      0.77       396
#          sci.electronics       0.60      0.59      0.59       393
#                  sci.med       0.79      0.77      0.78       396
#                sci.space       0.74      0.72      0.73       394
#   soc.religion.christian       0.63      0.83      0.71       398
#       talk.politics.guns       0.58      0.71      0.64       364
#    talk.politics.mideast       0.81      0.74      0.78       376
#       talk.politics.misc       0.56      0.48      0.51       310
#       talk.religion.misc       0.54      0.22      0.32       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time without сorpus preprocessing: 5.010745999999983
#
# Most frequent words deleted - 0
# Least frequent words deleted - 25000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.50      0.46      0.48       319
#            comp.graphics       0.66      0.72      0.69       389
#  comp.os.ms-windows.misc       0.63      0.64      0.63       394
# comp.sys.ibm.pc.hardware       0.70      0.64      0.67       392
#    comp.sys.mac.hardware       0.77      0.71      0.74       385
#           comp.windows.x       0.81      0.71      0.75       395
#             misc.forsale       0.76      0.81      0.79       390
#                rec.autos       0.82      0.68      0.75       396
#          rec.motorcycles       0.77      0.78      0.78       398
#       rec.sport.baseball       0.55      0.84      0.66       397
#         rec.sport.hockey       0.86      0.89      0.87       399
#                sci.crypt       0.84      0.72      0.77       396
#          sci.electronics       0.63      0.57      0.60       393
#                  sci.med       0.74      0.78      0.76       396
#                sci.space       0.71      0.75      0.73       394
#   soc.religion.christian       0.61      0.83      0.70       398
#       talk.politics.guns       0.58      0.67      0.62       364
#    talk.politics.mideast       0.79      0.77      0.78       376
#       talk.politics.misc       0.60      0.43      0.50       310
#       talk.religion.misc       0.58      0.22      0.31       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time without сorpus preprocessing: 4.758897999999988
#
# Most frequent words deleted - 0
# Least frequent words deleted - 40000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.58      0.47      0.52       319
#            comp.graphics       0.68      0.70      0.69       389
#  comp.os.ms-windows.misc       0.64      0.61      0.63       394
# comp.sys.ibm.pc.hardware       0.66      0.66      0.66       392
#    comp.sys.mac.hardware       0.77      0.71      0.74       385
#           comp.windows.x       0.81      0.71      0.75       395
#             misc.forsale       0.75      0.81      0.78       390
#                rec.autos       0.77      0.71      0.74       396
#          rec.motorcycles       0.75      0.77      0.76       398
#       rec.sport.baseball       0.52      0.83      0.64       397
#         rec.sport.hockey       0.84      0.89      0.86       399
#                sci.crypt       0.81      0.72      0.76       396
#          sci.electronics       0.63      0.55      0.58       393
#                  sci.med       0.77      0.77      0.77       396
#                sci.space       0.71      0.76      0.73       394
#   soc.religion.christian       0.65      0.81      0.72       398
#       talk.politics.guns       0.61      0.67      0.64       364
#    talk.politics.mideast       0.83      0.75      0.79       376
#       talk.politics.misc       0.52      0.48      0.50       310
#       talk.religion.misc       0.53      0.24      0.33       251
#
#              avg / total       0.70      0.69      0.69      7532
#
# Time without сorpus preprocessing: 5.876501000000019
#
# Most frequent words deleted - 0
# Least frequent words deleted - 55000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.53      0.49      0.51       319
#            comp.graphics       0.68      0.71      0.69       389
#  comp.os.ms-windows.misc       0.65      0.61      0.63       394
# comp.sys.ibm.pc.hardware       0.65      0.67      0.66       392
#    comp.sys.mac.hardware       0.76      0.71      0.73       385
#           comp.windows.x       0.79      0.71      0.75       395
#             misc.forsale       0.78      0.80      0.79       390
#                rec.autos       0.80      0.69      0.74       396
#          rec.motorcycles       0.79      0.75      0.77       398
#       rec.sport.baseball       0.85      0.78      0.81       397
#         rec.sport.hockey       0.55      0.91      0.69       399
#                sci.crypt       0.84      0.71      0.77       396
#          sci.electronics       0.55      0.62      0.58       393
#                  sci.med       0.76      0.78      0.77       396
#                sci.space       0.72      0.75      0.73       394
#   soc.religion.christian       0.67      0.79      0.72       398
#       talk.politics.guns       0.60      0.67      0.63       364
#    talk.politics.mideast       0.78      0.76      0.77       376
#       talk.politics.misc       0.59      0.48      0.53       310
#       talk.religion.misc       0.52      0.22      0.31       251
#
#              avg / total       0.70      0.69      0.69      7532
#
# Time without сorpus preprocessing: 4.818787000000043
#
# Most frequent words deleted - 0
# Least frequent words deleted - 70000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.52      0.48      0.50       319
#            comp.graphics       0.65      0.72      0.68       389
#  comp.os.ms-windows.misc       0.63      0.64      0.63       394
# comp.sys.ibm.pc.hardware       0.72      0.58      0.64       392
#    comp.sys.mac.hardware       0.76      0.71      0.73       385
#           comp.windows.x       0.82      0.70      0.75       395
#             misc.forsale       0.74      0.82      0.77       390
#                rec.autos       0.79      0.68      0.73       396
#          rec.motorcycles       0.79      0.74      0.77       398
#       rec.sport.baseball       0.53      0.84      0.65       397
#         rec.sport.hockey       0.86      0.89      0.87       399
#                sci.crypt       0.83      0.71      0.76       396
#          sci.electronics       0.62      0.58      0.60       393
#                  sci.med       0.78      0.78      0.78       396
#                sci.space       0.73      0.75      0.74       394
#   soc.religion.christian       0.62      0.83      0.71       398
#       talk.politics.guns       0.52      0.74      0.61       364
#    talk.politics.mideast       0.83      0.74      0.78       376
#       talk.politics.misc       0.59      0.44      0.51       310
#       talk.religion.misc       0.55      0.20      0.30       251
#
#              avg / total       0.70      0.69      0.69      7532
# Time without сorpus preprocessing: 5.463606999999911
#
# Most frequent words deleted - 0
# Least frequent words deleted - 85000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.50      0.46      0.48       319
#            comp.graphics       0.67      0.70      0.68       389
#  comp.os.ms-windows.misc       0.57      0.65      0.61       394
# comp.sys.ibm.pc.hardware       0.66      0.60      0.63       392
#    comp.sys.mac.hardware       0.75      0.69      0.72       385
#           comp.windows.x       0.82      0.68      0.74       395
#             misc.forsale       0.75      0.80      0.77       390
#                rec.autos       0.80      0.64      0.71       396
#          rec.motorcycles       0.73      0.76      0.74       398
#       rec.sport.baseball       0.53      0.82      0.64       397
#         rec.sport.hockey       0.83      0.89      0.86       399
#                sci.crypt       0.75      0.72      0.74       396
#          sci.electronics       0.58      0.55      0.57       393
#                  sci.med       0.77      0.76      0.76       396
#                sci.space       0.74      0.72      0.73       394
#   soc.religion.christian       0.64      0.79      0.71       398
#       talk.politics.guns       0.57      0.68      0.62       364
#    talk.politics.mideast       0.80      0.74      0.77       376
#       talk.politics.misc       0.57      0.44      0.49       310
#       talk.religion.misc       0.53      0.22      0.31       251
#
#              avg / total       0.68      0.68      0.67      7532
#
# Time without сorpus preprocessing: 5.808292000000051
#
# Most frequent words deleted - 0
# Least frequent words deleted - 90000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.49      0.45      0.47       319
#            comp.graphics       0.64      0.65      0.65       389
#  comp.os.ms-windows.misc       0.60      0.63      0.61       394
# comp.sys.ibm.pc.hardware       0.64      0.59      0.62       392
#    comp.sys.mac.hardware       0.75      0.64      0.69       385
#           comp.windows.x       0.78      0.68      0.73       395
#             misc.forsale       0.72      0.81      0.76       390
#                rec.autos       0.73      0.66      0.69       396
#          rec.motorcycles       0.74      0.72      0.73       398
#       rec.sport.baseball       0.53      0.80      0.63       397
#         rec.sport.hockey       0.79      0.88      0.83       399
#                sci.crypt       0.76      0.72      0.74       396
#          sci.electronics       0.59      0.52      0.55       393
#                  sci.med       0.71      0.77      0.74       396
#                sci.space       0.74      0.73      0.74       394
#   soc.religion.christian       0.65      0.75      0.70       398
#       talk.politics.guns       0.57      0.66      0.61       364
#    talk.politics.mideast       0.74      0.75      0.74       376
#       talk.politics.misc       0.56      0.38      0.45       310
#       talk.religion.misc       0.43      0.24      0.31       251
#
#              avg / total       0.66      0.67      0.66      7532
#
# Time without сorpus preprocessing: 4.947554000000082
#
# Most frequent words deleted - 10000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.44      0.35      0.39       319
#            comp.graphics       0.55      0.44      0.49       389
#  comp.os.ms-windows.misc       0.48      0.34      0.39       394
# comp.sys.ibm.pc.hardware       0.49      0.44      0.46       392
#    comp.sys.mac.hardware       0.56      0.45      0.50       385
#           comp.windows.x       0.22      0.65      0.33       395
#             misc.forsale       0.55      0.48      0.52       390
#                rec.autos       0.55      0.53      0.54       396
#          rec.motorcycles       0.58      0.43      0.50       398
#       rec.sport.baseball       0.67      0.64      0.65       397
#         rec.sport.hockey       0.65      0.60      0.62       399
#                sci.crypt       0.46      0.43      0.45       396
#          sci.electronics       0.44      0.35      0.39       393
#                  sci.med       0.62      0.59      0.60       396
#                sci.space       0.55      0.50      0.53       394
#   soc.religion.christian       0.52      0.64      0.57       398
#       talk.politics.guns       0.38      0.37      0.37       364
#    talk.politics.mideast       0.60      0.62      0.61       376
#       talk.politics.misc       0.44      0.34      0.38       310
#       talk.religion.misc       0.29      0.20      0.23       251
#
#              avg / total       0.51      0.48      0.48      7532
#
# Time without сorpus preprocessing: 4.973023000000012
#
# Most frequent words deleted - 25000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.28      0.17      0.21       319
#            comp.graphics       0.44      0.28      0.34       389
#  comp.os.ms-windows.misc       0.33      0.16      0.22       394
# comp.sys.ibm.pc.hardware       0.41      0.24      0.31       392
#    comp.sys.mac.hardware       0.41      0.23      0.29       385
#           comp.windows.x       0.11      0.68      0.18       395
#             misc.forsale       0.48      0.33      0.39       390
#                rec.autos       0.42      0.33      0.37       396
#          rec.motorcycles       0.46      0.31      0.37       398
#       rec.sport.baseball       0.54      0.37      0.44       397
#         rec.sport.hockey       0.52      0.38      0.44       399
#                sci.crypt       0.34      0.23      0.27       396
#          sci.electronics       0.38      0.21      0.27       393
#                  sci.med       0.46      0.44      0.45       396
#                sci.space       0.41      0.35      0.38       394
#   soc.religion.christian       0.44      0.44      0.44       398
#       talk.politics.guns       0.30      0.24      0.27       364
#    talk.politics.mideast       0.54      0.41      0.47       376
#       talk.politics.misc       0.29      0.17      0.22       310
#       talk.religion.misc       0.22      0.15      0.18       251
#
#              avg / total       0.40      0.31      0.33      7532
#
# Time without сorpus preprocessing: 5.169709000000012
#
# Most frequent words deleted - 40000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.28      0.13      0.18       319
#            comp.graphics       0.39      0.17      0.23       389
#  comp.os.ms-windows.misc       0.25      0.09      0.13       394
# comp.sys.ibm.pc.hardware       0.07      0.65      0.12       392
#    comp.sys.mac.hardware       0.42      0.17      0.24       385
#           comp.windows.x       0.57      0.32      0.41       395
#             misc.forsale       0.48      0.24      0.32       390
#                rec.autos       0.42      0.21      0.28       396
#          rec.motorcycles       0.40      0.20      0.27       398
#       rec.sport.baseball       0.46      0.21      0.29       397
#         rec.sport.hockey       0.58      0.28      0.37       399
#                sci.crypt       0.26      0.15      0.19       396
#          sci.electronics       0.31      0.13      0.19       393
#                  sci.med       0.44      0.30      0.36       396
#                sci.space       0.34      0.22      0.27       394
#   soc.religion.christian       0.43      0.32      0.37       398
#       talk.politics.guns       0.22      0.12      0.15       364
#    talk.politics.mideast       0.46      0.28      0.35       376
#       talk.politics.misc       0.22      0.11      0.15       310
#       talk.religion.misc       0.17      0.12      0.14       251
#
#              avg / total       0.37      0.23      0.26      7532
#
# Time without сorpus preprocessing: 4.615959999999973
#
# Most frequent words deleted - 55000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.30      0.10      0.15       319
#            comp.graphics       0.34      0.14      0.19       389
#  comp.os.ms-windows.misc       0.22      0.07      0.10       394
# comp.sys.ibm.pc.hardware       0.33      0.10      0.16       392
#    comp.sys.mac.hardware       0.38      0.12      0.19       385
#           comp.windows.x       0.55      0.23      0.33       395
#             misc.forsale       0.44      0.18      0.25       390
#                rec.autos       0.42      0.16      0.23       396
#          rec.motorcycles       0.33      0.12      0.18       398
#       rec.sport.baseball       0.47      0.16      0.24       397
#         rec.sport.hockey       0.56      0.21      0.30       399
#                sci.crypt       0.22      0.11      0.14       396
#          sci.electronics       0.32      0.10      0.16       393
#                  sci.med       0.38      0.23      0.29       396
#                sci.space       0.31      0.18      0.23       394
#   soc.religion.christian       0.06      0.72      0.11       398
#       talk.politics.guns       0.25      0.11      0.15       364
#    talk.politics.mideast       0.44      0.24      0.31       376
#       talk.politics.misc       0.23      0.08      0.12       310
#       talk.religion.misc       0.17      0.10      0.12       251
#
#              avg / total       0.34      0.18      0.20      7532
# Time without сorpus preprocessing: 4.757506000000035
#
# Most frequent words deleted - 70000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.23      0.06      0.09       319
#            comp.graphics       0.40      0.11      0.18       389
#  comp.os.ms-windows.misc       0.22      0.06      0.09       394
# comp.sys.ibm.pc.hardware       0.37      0.08      0.13       392
#    comp.sys.mac.hardware       0.42      0.08      0.13       385
#           comp.windows.x       0.47      0.15      0.22       395
#             misc.forsale       0.39      0.13      0.19       390
#                rec.autos       0.47      0.11      0.18       396
#          rec.motorcycles       0.27      0.07      0.11       398
#       rec.sport.baseball       0.46      0.11      0.18       397
#         rec.sport.hockey       0.60      0.20      0.29       399
#                sci.crypt       0.23      0.08      0.12       396
#          sci.electronics       0.30      0.08      0.12       393
#                  sci.med       0.33      0.15      0.21       396
#                sci.space       0.29      0.12      0.17       394
#   soc.religion.christian       0.44      0.25      0.32       398
#       talk.politics.guns       0.26      0.10      0.14       364
#    talk.politics.mideast       0.05      0.76      0.10       376
#       talk.politics.misc       0.21      0.05      0.08       310
#       talk.religion.misc       0.17      0.08      0.10       251
#
#              avg / total       0.34      0.14      0.16      7532
#
# Time without сorpus preprocessing: 4.8950660000000425
#
# Most frequent words deleted - 85000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.29      0.05      0.09       319
#            comp.graphics       0.42      0.06      0.11       389
#  comp.os.ms-windows.misc       0.21      0.04      0.07       394
# comp.sys.ibm.pc.hardware       0.42      0.04      0.08       392
#    comp.sys.mac.hardware       0.41      0.03      0.06       385
#           comp.windows.x       0.46      0.07      0.12       395
#             misc.forsale       0.37      0.08      0.13       390
#                rec.autos       0.06      0.85      0.10       396
#          rec.motorcycles       0.31      0.05      0.08       398
#       rec.sport.baseball       0.46      0.06      0.11       397
#         rec.sport.hockey       0.61      0.16      0.25       399
#                sci.crypt       0.20      0.03      0.06       396
#          sci.electronics       0.24      0.04      0.07       393
#                  sci.med       0.34      0.08      0.12       396
#                sci.space       0.28      0.09      0.13       394
#   soc.religion.christian       0.43      0.15      0.22       398
#       talk.politics.guns       0.28      0.07      0.11       364
#    talk.politics.mideast       0.37      0.12      0.19       376
#       talk.politics.misc       0.25      0.04      0.06       310
#       talk.religion.misc       0.07      0.01      0.02       251
#
#              avg / total       0.33      0.11      0.11      7532
#
# Time without сorpus preprocessing: 5.0591249999999945
#
# Most frequent words deleted - 90000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.26      0.04      0.07       319
#            comp.graphics       0.32      0.03      0.06       389
#  comp.os.ms-windows.misc       0.16      0.03      0.04       394
# comp.sys.ibm.pc.hardware       0.38      0.03      0.05       392
#    comp.sys.mac.hardware       0.18      0.01      0.01       385
#           comp.windows.x       0.52      0.04      0.08       395
#             misc.forsale       0.29      0.03      0.05       390
#                rec.autos       0.48      0.03      0.06       396
#          rec.motorcycles       0.06      0.94      0.10       398
#       rec.sport.baseball       0.48      0.03      0.05       397
#         rec.sport.hockey       0.55      0.06      0.10       399
#                sci.crypt       0.22      0.02      0.04       396
#          sci.electronics       0.35      0.02      0.03       393
#                  sci.med       0.40      0.05      0.09       396
#                sci.space       0.28      0.05      0.08       394
#   soc.religion.christian       0.42      0.09      0.15       398
#       talk.politics.guns       0.24      0.03      0.06       364
#    talk.politics.mideast       0.47      0.07      0.12       376
#       talk.politics.misc       0.21      0.02      0.04       310
#       talk.religion.misc       0.12      0.01      0.02       251
#
#              avg / total       0.32      0.08      0.07      7532
#
# Time without сorpus preprocessing: 4.84514200000001
#
# Most frequent words deleted - 10000
# Least frequent words deleted - 10000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.45      0.36      0.40       319
#            comp.graphics       0.53      0.43      0.48       389
#  comp.os.ms-windows.misc       0.46      0.31      0.37       394
# comp.sys.ibm.pc.hardware       0.48      0.43      0.46       392
#    comp.sys.mac.hardware       0.56      0.44      0.49       385
#           comp.windows.x       0.66      0.52      0.58       395
#             misc.forsale       0.52      0.48      0.50       390
#                rec.autos       0.57      0.52      0.54       396
#          rec.motorcycles       0.19      0.58      0.29       398
#       rec.sport.baseball       0.67      0.63      0.65       397
#         rec.sport.hockey       0.63      0.59      0.61       399
#                sci.crypt       0.43      0.41      0.42       396
#          sci.electronics       0.44      0.36      0.39       393
#                  sci.med       0.61      0.58      0.60       396
#                sci.space       0.57      0.49      0.53       394
#   soc.religion.christian       0.52      0.64      0.57       398
#       talk.politics.guns       0.40      0.36      0.38       364
#    talk.politics.mideast       0.59      0.62      0.60       376
#       talk.politics.misc       0.44      0.33      0.38       310
#       talk.religion.misc       0.28      0.20      0.23       251
#
#              avg / total       0.50      0.47      0.48      7532
#
# Time without сorpus preprocessing: 4.957059999999956
#
# Most frequent words deleted - 20000
# Least frequent words deleted - 20000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.35      0.20      0.25       319
#            comp.graphics       0.42      0.28      0.33       389
#  comp.os.ms-windows.misc       0.39      0.18      0.25       394
# comp.sys.ibm.pc.hardware       0.46      0.29      0.35       392
#    comp.sys.mac.hardware       0.46      0.29      0.35       385
#           comp.windows.x       0.58      0.40      0.47       395
#             misc.forsale       0.46      0.34      0.39       390
#                rec.autos       0.45      0.36      0.40       396
#          rec.motorcycles       0.48      0.33      0.39       398
#       rec.sport.baseball       0.62      0.44      0.52       397
#         rec.sport.hockey       0.12      0.69      0.21       399
#                sci.crypt       0.37      0.31      0.33       396
#          sci.electronics       0.38      0.26      0.31       393
#                  sci.med       0.50      0.48      0.49       396
#                sci.space       0.42      0.37      0.39       394
#   soc.religion.christian       0.46      0.45      0.45       398
#       talk.politics.guns       0.29      0.23      0.26       364
#    talk.politics.mideast       0.50      0.43      0.46       376
#       talk.politics.misc       0.33      0.20      0.25       310
#       talk.religion.misc       0.21      0.13      0.16       251
#
#              avg / total       0.42      0.34      0.36      7532
#
# Time without сorpus preprocessing: 5.713567000000012
#
# Most frequent words deleted - 30000
# Least frequent words deleted - 30000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.25      0.13      0.17       319
#            comp.graphics       0.40      0.18      0.25       389
#  comp.os.ms-windows.misc       0.25      0.10      0.14       394
# comp.sys.ibm.pc.hardware       0.40      0.18      0.25       392
#    comp.sys.mac.hardware       0.39      0.16      0.22       385
#           comp.windows.x       0.57      0.30      0.39       395
#             misc.forsale       0.48      0.26      0.34       390
#                rec.autos       0.36      0.20      0.26       396
#          rec.motorcycles       0.46      0.21      0.29       398
#       rec.sport.baseball       0.53      0.26      0.35       397
#         rec.sport.hockey       0.52      0.28      0.36       399
#                sci.crypt       0.26      0.16      0.20       396
#          sci.electronics       0.34      0.17      0.23       393
#                  sci.med       0.48      0.33      0.39       396
#                sci.space       0.37      0.23      0.29       394
#   soc.religion.christian       0.43      0.32      0.37       398
#       talk.politics.guns       0.25      0.14      0.18       364
#    talk.politics.mideast       0.06      0.63      0.12       376
#       talk.politics.misc       0.27      0.15      0.19       310
#       talk.religion.misc       0.18      0.10      0.13       251
#
#              avg / total       0.37      0.23      0.26      7532
# Time without сorpus preprocessing: 4.9754760000000715
#
# Most frequent words deleted - 40000
# Least frequent words deleted - 40000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.23      0.08      0.11       319
#            comp.graphics       0.44      0.07      0.12       389
#  comp.os.ms-windows.misc       0.16      0.04      0.06       394
# comp.sys.ibm.pc.hardware       0.27      0.07      0.11       392
#    comp.sys.mac.hardware       0.42      0.08      0.14       385
#           comp.windows.x       0.53      0.18      0.27       395
#             misc.forsale       0.52      0.14      0.22       390
#                rec.autos       0.32      0.09      0.14       396
#          rec.motorcycles       0.39      0.11      0.17       398
#       rec.sport.baseball       0.48      0.13      0.20       397
#         rec.sport.hockey       0.45      0.13      0.20       399
#                sci.crypt       0.28      0.08      0.13       396
#          sci.electronics       0.06      0.83      0.11       393
#                  sci.med       0.49      0.19      0.28       396
#                sci.space       0.33      0.10      0.15       394
#   soc.religion.christian       0.40      0.18      0.25       398
#       talk.politics.guns       0.14      0.04      0.06       364
#    talk.politics.mideast       0.39      0.15      0.21       376
#       talk.politics.misc       0.18      0.07      0.10       310
#       talk.religion.misc       0.20      0.07      0.10       251
#
#              avg / total       0.34      0.14      0.16      7532
#
# Time without сorpus preprocessing: 5.101591999999982

# %% [markdown]
# ## 4. Классификация после стемминга

# %%
twenty_train.data = stemming_train_texts.copy()
twenty_test.data = stemming_test_texts.copy()

# %%
for el in deletions:
    print("Most frequent words deleted -", el[0])
    print("Least frequent words deleted -", el[1])
    update_forbidden_words(forbiddenWords, el[0], el[1])
    print("RESULTS:")
    deleteWordsStats(twenty_train, twenty_test, forbiddenWords)
    print("Time after stemming:", countTime(twenty_train, twenty_test, 1))
    print()
# Out:
# Most frequent words deleted - 0
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.56      0.45      0.50       319
#            comp.graphics       0.71      0.71      0.71       389
#  comp.os.ms-windows.misc       0.65      0.58      0.61       394
# comp.sys.ibm.pc.hardware       0.65      0.65      0.65       392
#    comp.sys.mac.hardware       0.76      0.70      0.73       385
#           comp.windows.x       0.79      0.74      0.76       395
#             misc.forsale       0.76      0.82      0.79       390
#                rec.autos       0.80      0.71      0.75       396
#          rec.motorcycles       0.76      0.76      0.76       398
#       rec.sport.baseball       0.55      0.87      0.68       397
#         rec.sport.hockey       0.88      0.91      0.89       399
#                sci.crypt       0.84      0.72      0.77       396
#          sci.electronics       0.62      0.57      0.59       393
#                  sci.med       0.77      0.79      0.78       396
#                sci.space       0.74      0.74      0.74       394
#   soc.religion.christian       0.66      0.80      0.73       398
#       talk.politics.guns       0.58      0.69      0.63       364
#    talk.politics.mideast       0.80      0.77      0.78       376
#       talk.politics.misc       0.51      0.48      0.50       310
#       talk.religion.misc       0.45      0.26      0.33       251
#
#              avg / total       0.70      0.70      0.70      7532
#
# Time after stemming: 4.359284000000002
#
# Most frequent words deleted - 0
# Least frequent words deleted - 10000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.55      0.49      0.52       319
#            comp.graphics       0.70      0.72      0.71       389
#  comp.os.ms-windows.misc       0.61      0.61      0.61       394
# comp.sys.ibm.pc.hardware       0.70      0.62      0.66       392
#    comp.sys.mac.hardware       0.73      0.70      0.72       385
#           comp.windows.x       0.81      0.71      0.76       395
#             misc.forsale       0.73      0.82      0.77       390
#                rec.autos       0.80      0.72      0.76       396
#          rec.motorcycles       0.80      0.77      0.78       398
#       rec.sport.baseball       0.56      0.84      0.67       397
#         rec.sport.hockey       0.85      0.91      0.88       399
#                sci.crypt       0.87      0.70      0.78       396
#          sci.electronics       0.63      0.57      0.60       393
#                  sci.med       0.71      0.82      0.76       396
#                sci.space       0.73      0.75      0.74       394
#   soc.religion.christian       0.64      0.81      0.72       398
#       talk.politics.guns       0.55      0.72      0.62       364
#    talk.politics.mideast       0.77      0.76      0.77       376
#       talk.politics.misc       0.61      0.46      0.53       310
#       talk.religion.misc       0.55      0.18      0.28       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time after stemming: 5.197746000000052
#
# Most frequent words deleted - 0
# Least frequent words deleted - 25000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.59      0.46      0.52       319
#            comp.graphics       0.69      0.72      0.71       389
#  comp.os.ms-windows.misc       0.65      0.58      0.61       394
# comp.sys.ibm.pc.hardware       0.66      0.67      0.66       392
#    comp.sys.mac.hardware       0.72      0.72      0.72       385
#           comp.windows.x       0.81      0.72      0.76       395
#             misc.forsale       0.76      0.82      0.79       390
#                rec.autos       0.76      0.72      0.74       396
#          rec.motorcycles       0.78      0.75      0.76       398
#       rec.sport.baseball       0.55      0.85      0.67       397
#         rec.sport.hockey       0.84      0.91      0.87       399
#                sci.crypt       0.84      0.73      0.78       396
#          sci.electronics       0.62      0.56      0.59       393
#                  sci.med       0.79      0.79      0.79       396
#                sci.space       0.70      0.77      0.73       394
#   soc.religion.christian       0.65      0.82      0.73       398
#       talk.politics.guns       0.59      0.70      0.64       364
#    talk.politics.mideast       0.81      0.77      0.79       376
#       talk.politics.misc       0.58      0.46      0.52       310
#       talk.religion.misc       0.53      0.23      0.32       251
#
#              avg / total       0.70      0.70      0.70      7532
#
# Time after stemming: 4.157965999999988
#
# Most frequent words deleted - 0
# Least frequent words deleted - 40000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.58      0.43      0.49       319
#            comp.graphics       0.67      0.74      0.70       389
#  comp.os.ms-windows.misc       0.62      0.61      0.62       394
# comp.sys.ibm.pc.hardware       0.71      0.63      0.67       392
#    comp.sys.mac.hardware       0.72      0.72      0.72       385
#           comp.windows.x       0.84      0.70      0.76       395
#             misc.forsale       0.75      0.82      0.78       390
#                rec.autos       0.78      0.72      0.75       396
#          rec.motorcycles       0.75      0.76      0.76       398
#       rec.sport.baseball       0.56      0.84      0.67       397
#         rec.sport.hockey       0.86      0.91      0.88       399
#                sci.crypt       0.76      0.74      0.75       396
#          sci.electronics       0.58      0.56      0.57       393
#                  sci.med       0.75      0.81      0.78       396
#                sci.space       0.75      0.72      0.74       394
#   soc.religion.christian       0.63      0.81      0.71       398
#       talk.politics.guns       0.59      0.68      0.63       364
#    talk.politics.mideast       0.82      0.76      0.79       376
#       talk.politics.misc       0.59      0.43      0.50       310
#       talk.religion.misc       0.45      0.25      0.32       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time after stemming: 5.3852379999999584
#
# Most frequent words deleted - 0
# Least frequent words deleted - 55000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.48      0.52      0.50       319
#            comp.graphics       0.67      0.71      0.69       389
#  comp.os.ms-windows.misc       0.64      0.56      0.60       394
# comp.sys.ibm.pc.hardware       0.65      0.66      0.66       392
#    comp.sys.mac.hardware       0.70      0.73      0.72       385
#           comp.windows.x       0.79      0.72      0.76       395
#             misc.forsale       0.78      0.80      0.79       390
#                rec.autos       0.80      0.70      0.75       396
#          rec.motorcycles       0.78      0.77      0.77       398
#       rec.sport.baseball       0.54      0.83      0.66       397
#         rec.sport.hockey       0.83      0.91      0.87       399
#                sci.crypt       0.80      0.73      0.77       396
#          sci.electronics       0.64      0.52      0.58       393
#                  sci.med       0.77      0.81      0.79       396
#                sci.space       0.75      0.75      0.75       394
#   soc.religion.christian       0.66      0.79      0.72       398
#       talk.politics.guns       0.58      0.68      0.63       364
#    talk.politics.mideast       0.85      0.73      0.78       376
#       talk.politics.misc       0.58      0.45      0.50       310
#       talk.religion.misc       0.47      0.26      0.33       251
#
#              avg / total       0.70      0.69      0.69      7532
#
# Time after stemming: 4.703753000000006
#
# Most frequent words deleted - 0
# Least frequent words deleted - 70000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.52      0.50      0.51       319
#            comp.graphics       0.66      0.69      0.68       389
#  comp.os.ms-windows.misc       0.62      0.61      0.61       394
# comp.sys.ibm.pc.hardware       0.68      0.64      0.66       392
#    comp.sys.mac.hardware       0.72      0.71      0.72       385
#           comp.windows.x       0.78      0.71      0.74       395
#             misc.forsale       0.72      0.81      0.76       390
#                rec.autos       0.75      0.72      0.74       396
#          rec.motorcycles       0.79      0.75      0.77       398
#       rec.sport.baseball       0.55      0.81      0.66       397
#         rec.sport.hockey       0.83      0.90      0.86       399
#                sci.crypt       0.79      0.74      0.76       396
#          sci.electronics       0.66      0.51      0.58       393
#                  sci.med       0.74      0.81      0.78       396
#                sci.space       0.73      0.75      0.74       394
#   soc.religion.christian       0.65      0.81      0.72       398
#       talk.politics.guns       0.58      0.67      0.63       364
#    talk.politics.mideast       0.80      0.76      0.78       376
#       talk.politics.misc       0.58      0.45      0.51       310
#       talk.religion.misc       0.53      0.20      0.29       251
#
#              avg / total       0.69      0.69      0.69      7532
# Time after stemming: 4.663707999999929
#
# Most frequent words deleted - 0
# Least frequent words deleted - 85000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.52      0.46      0.49       319
#            comp.graphics       0.71      0.66      0.69       389
#  comp.os.ms-windows.misc       0.61      0.61      0.61       394
# comp.sys.ibm.pc.hardware       0.61      0.65      0.63       392
#    comp.sys.mac.hardware       0.70      0.69      0.70       385
#           comp.windows.x       0.79      0.71      0.74       395
#             misc.forsale       0.74      0.81      0.77       390
#                rec.autos       0.79      0.68      0.73       396
#          rec.motorcycles       0.76      0.74      0.75       398
#       rec.sport.baseball       0.53      0.83      0.65       397
#         rec.sport.hockey       0.85      0.89      0.87       399
#                sci.crypt       0.81      0.72      0.76       396
#          sci.electronics       0.63      0.51      0.57       393
#                  sci.med       0.77      0.79      0.78       396
#                sci.space       0.69      0.77      0.73       394
#   soc.religion.christian       0.67      0.76      0.71       398
#       talk.politics.guns       0.59      0.67      0.62       364
#    talk.politics.mideast       0.73      0.77      0.75       376
#       talk.politics.misc       0.56      0.42      0.48       310
#       talk.religion.misc       0.48      0.23      0.31       251
#
#              avg / total       0.68      0.68      0.68      7532
#
# Time after stemming: 4.9091640000000325
#
# Most frequent words deleted - 0
# Least frequent words deleted - 90000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.54      0.44      0.49       319
#            comp.graphics       0.66      0.66      0.66       389
#  comp.os.ms-windows.misc       0.60      0.61      0.60       394
# comp.sys.ibm.pc.hardware       0.68      0.57      0.62       392
#    comp.sys.mac.hardware       0.68      0.66      0.67       385
#           comp.windows.x       0.76      0.70      0.73       395
#             misc.forsale       0.73      0.81      0.76       390
#                rec.autos       0.70      0.68      0.69       396
#          rec.motorcycles       0.76      0.71      0.73       398
#       rec.sport.baseball       0.51      0.82      0.63       397
#         rec.sport.hockey       0.84      0.87      0.85       399
#                sci.crypt       0.80      0.71      0.76       396
#          sci.electronics       0.60      0.50      0.54       393
#                  sci.med       0.69      0.79      0.74       396
#                sci.space       0.76      0.72      0.74       394
#   soc.religion.christian       0.65      0.76      0.70       398
#       talk.politics.guns       0.54      0.69      0.60       364
#    talk.politics.mideast       0.78      0.73      0.76       376
#       talk.politics.misc       0.51      0.43      0.47       310
#       talk.religion.misc       0.41      0.18      0.25       251
#
#              avg / total       0.67      0.67      0.66      7532
#
# Time after stemming: 4.281415000000038
#
# Most frequent words deleted - 10000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.53      0.37      0.44       319
#            comp.graphics       0.57      0.54      0.55       389
#  comp.os.ms-windows.misc       0.44      0.39      0.41       394
# comp.sys.ibm.pc.hardware       0.53      0.51      0.52       392
#    comp.sys.mac.hardware       0.54      0.56      0.55       385
#           comp.windows.x       0.60      0.53      0.57       395
#             misc.forsale       0.59      0.60      0.59       390
#                rec.autos       0.60      0.58      0.59       396
#          rec.motorcycles       0.61      0.53      0.57       398
#       rec.sport.baseball       0.41      0.78      0.54       397
#         rec.sport.hockey       0.70      0.75      0.73       399
#                sci.crypt       0.60      0.57      0.58       396
#          sci.electronics       0.46      0.44      0.45       393
#                  sci.med       0.68      0.71      0.69       396
#                sci.space       0.63      0.61      0.62       394
#   soc.religion.christian       0.58      0.68      0.63       398
#       talk.politics.guns       0.43      0.46      0.45       364
#    talk.politics.mideast       0.66      0.62      0.64       376
#       talk.politics.misc       0.46      0.39      0.42       310
#       talk.religion.misc       0.33      0.19      0.24       251
#
#              avg / total       0.55      0.55      0.55      7532
#
# Time after stemming: 4.507624999999962
#
# Most frequent words deleted - 25000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.42      0.33      0.37       319
#            comp.graphics       0.42      0.53      0.47       389
#  comp.os.ms-windows.misc       0.41      0.25      0.31       394
# comp.sys.ibm.pc.hardware       0.45      0.38      0.41       392
#    comp.sys.mac.hardware       0.51      0.47      0.49       385
#           comp.windows.x       0.49      0.49      0.49       395
#             misc.forsale       0.52      0.61      0.56       390
#                rec.autos       0.56      0.48      0.52       396
#          rec.motorcycles       0.54      0.44      0.49       398
#       rec.sport.baseball       0.34      0.72      0.46       397
#         rec.sport.hockey       0.72      0.68      0.70       399
#                sci.crypt       0.53      0.53      0.53       396
#          sci.electronics       0.40      0.37      0.38       393
#                  sci.med       0.62      0.69      0.65       396
#                sci.space       0.58      0.59      0.59       394
#   soc.religion.christian       0.57      0.65      0.61       398
#       talk.politics.guns       0.42      0.39      0.40       364
#    talk.politics.mideast       0.63      0.58      0.60       376
#       talk.politics.misc       0.40      0.35      0.38       310
#       talk.religion.misc       0.28      0.13      0.18       251
#
#              avg / total       0.50      0.49      0.49      7532
#
# Time after stemming: 4.100508999999988
#
# Most frequent words deleted - 40000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.40      0.32      0.35       319
#            comp.graphics       0.44      0.48      0.46       389
#  comp.os.ms-windows.misc       0.30      0.26      0.28       394
# comp.sys.ibm.pc.hardware       0.36      0.33      0.35       392
#    comp.sys.mac.hardware       0.47      0.35      0.40       385
#           comp.windows.x       0.46      0.51      0.48       395
#             misc.forsale       0.57      0.58      0.58       390
#                rec.autos       0.49      0.41      0.45       396
#          rec.motorcycles       0.52      0.37      0.43       398
#       rec.sport.baseball       0.31      0.70      0.43       397
#         rec.sport.hockey       0.59      0.65      0.62       399
#                sci.crypt       0.46      0.54      0.50       396
#          sci.electronics       0.42      0.36      0.39       393
#                  sci.med       0.62      0.69      0.65       396
#                sci.space       0.61      0.56      0.58       394
#   soc.religion.christian       0.56      0.62      0.58       398
#       talk.politics.guns       0.39      0.38      0.39       364
#    talk.politics.mideast       0.67      0.56      0.61       376
#       talk.politics.misc       0.40      0.31      0.35       310
#       talk.religion.misc       0.20      0.10      0.13       251
#
#              avg / total       0.47      0.46      0.46      7532
#
# Time after stemming: 4.179638999999952
#
# Most frequent words deleted - 55000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.41      0.29      0.34       319
#            comp.graphics       0.42      0.39      0.40       389
#  comp.os.ms-windows.misc       0.31      0.24      0.27       394
# comp.sys.ibm.pc.hardware       0.37      0.29      0.33       392
#    comp.sys.mac.hardware       0.42      0.37      0.39       385
#           comp.windows.x       0.46      0.47      0.46       395
#             misc.forsale       0.53      0.57      0.55       390
#                rec.autos       0.47      0.42      0.44       396
#          rec.motorcycles       0.24      0.43      0.31       398
#       rec.sport.baseball       0.55      0.60      0.58       397
#         rec.sport.hockey       0.58      0.63      0.61       399
#                sci.crypt       0.48      0.51      0.49       396
#          sci.electronics       0.38      0.37      0.37       393
#                  sci.med       0.61      0.68      0.64       396
#                sci.space       0.60      0.56      0.58       394
#   soc.religion.christian       0.51      0.62      0.56       398
#       talk.politics.guns       0.39      0.34      0.36       364
#    talk.politics.mideast       0.58      0.59      0.59       376
#       talk.politics.misc       0.39      0.32      0.35       310
#       talk.religion.misc       0.19      0.10      0.13       251
#
#              avg / total       0.45      0.45      0.45      7532
# Time after stemming: 4.099104000000011
#
# Most frequent words deleted - 70000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.39      0.26      0.31       319
#            comp.graphics       0.44      0.37      0.40       389
#  comp.os.ms-windows.misc       0.32      0.22      0.26       394
# comp.sys.ibm.pc.hardware       0.38      0.35      0.36       392
#    comp.sys.mac.hardware       0.42      0.35      0.39       385
#           comp.windows.x       0.46      0.48      0.47       395
#             misc.forsale       0.54      0.58      0.56       390
#                rec.autos       0.49      0.44      0.46       396
#          rec.motorcycles       0.52      0.36      0.43       398
#       rec.sport.baseball       0.26      0.61      0.36       397
#         rec.sport.hockey       0.68      0.63      0.65       399
#                sci.crypt       0.47      0.53      0.50       396
#          sci.electronics       0.37      0.39      0.38       393
#                  sci.med       0.63      0.69      0.66       396
#                sci.space       0.56      0.57      0.57       394
#   soc.religion.christian       0.50      0.60      0.55       398
#       talk.politics.guns       0.37      0.36      0.37       364
#    talk.politics.mideast       0.61      0.60      0.60       376
#       talk.politics.misc       0.38      0.32      0.35       310
#       talk.religion.misc       0.17      0.08      0.11       251
#
#              avg / total       0.46      0.45      0.45      7532
#
# Time after stemming: 4.1874540000000025
#
# Most frequent words deleted - 85000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.35      0.32      0.33       319
#            comp.graphics       0.44      0.35      0.39       389
#  comp.os.ms-windows.misc       0.35      0.23      0.27       394
# comp.sys.ibm.pc.hardware       0.39      0.32      0.35       392
#    comp.sys.mac.hardware       0.41      0.36      0.38       385
#           comp.windows.x       0.44      0.51      0.47       395
#             misc.forsale       0.49      0.59      0.53       390
#                rec.autos       0.53      0.39      0.45       396
#          rec.motorcycles       0.21      0.46      0.29       398
#       rec.sport.baseball       0.52      0.50      0.51       397
#         rec.sport.hockey       0.65      0.65      0.65       399
#                sci.crypt       0.51      0.49      0.50       396
#          sci.electronics       0.37      0.34      0.35       393
#                  sci.med       0.60      0.67      0.63       396
#                sci.space       0.55      0.57      0.56       394
#   soc.religion.christian       0.52      0.60      0.56       398
#       talk.politics.guns       0.36      0.36      0.36       364
#    talk.politics.mideast       0.58      0.59      0.58       376
#       talk.politics.misc       0.38      0.31      0.34       310
#       talk.religion.misc       0.22      0.10      0.14       251
#
#              avg / total       0.45      0.44      0.44      7532
#
# Time after stemming: 4.189865999999938
#
# Most frequent words deleted - 90000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.38      0.28      0.32       319
#            comp.graphics       0.46      0.37      0.41       389
#  comp.os.ms-windows.misc       0.30      0.19      0.23       394
# comp.sys.ibm.pc.hardware       0.33      0.37      0.35       392
#    comp.sys.mac.hardware       0.41      0.31      0.35       385
#           comp.windows.x       0.49      0.45      0.47       395
#             misc.forsale       0.53      0.54      0.54       390
#                rec.autos       0.45      0.42      0.43       396
#          rec.motorcycles       0.22      0.46      0.29       398
#       rec.sport.baseball       0.52      0.52      0.52       397
#         rec.sport.hockey       0.61      0.61      0.61       399
#                sci.crypt       0.50      0.52      0.51       396
#          sci.electronics       0.33      0.38      0.36       393
#                  sci.med       0.61      0.67      0.64       396
#                sci.space       0.59      0.53      0.56       394
#   soc.religion.christian       0.50      0.61      0.55       398
#       talk.politics.guns       0.37      0.35      0.36       364
#    talk.politics.mideast       0.60      0.56      0.58       376
#       talk.politics.misc       0.39      0.33      0.36       310
#       talk.religion.misc       0.17      0.08      0.11       251
#
#              avg / total       0.44      0.44      0.44      7532
#
# Time after stemming: 4.578961999999933
#
# Most frequent words deleted - 10000
# Least frequent words deleted - 10000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.50      0.39      0.44       319
#            comp.graphics       0.51      0.58      0.55       389
#  comp.os.ms-windows.misc       0.45      0.37      0.41       394
# comp.sys.ibm.pc.hardware       0.50      0.54      0.52       392
#    comp.sys.mac.hardware       0.51      0.54      0.52       385
#           comp.windows.x       0.59      0.53      0.56       395
#             misc.forsale       0.60      0.61      0.60       390
#                rec.autos       0.58      0.59      0.59       396
#          rec.motorcycles       0.35      0.60      0.44       398
#       rec.sport.baseball       0.76      0.71      0.73       397
#         rec.sport.hockey       0.67      0.76      0.71       399
#                sci.crypt       0.58      0.58      0.58       396
#          sci.electronics       0.53      0.43      0.47       393
#                  sci.med       0.70      0.70      0.70       396
#                sci.space       0.67      0.60      0.64       394
#   soc.religion.christian       0.58      0.67      0.62       398
#       talk.politics.guns       0.45      0.46      0.45       364
#    talk.politics.mideast       0.69      0.61      0.64       376
#       talk.politics.misc       0.48      0.37      0.42       310
#       talk.religion.misc       0.34      0.21      0.26       251
#
#              avg / total       0.56      0.55      0.55      7532
#
# Time after stemming: 4.1556000000000495
#
# Most frequent words deleted - 20000
# Least frequent words deleted - 20000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.41      0.33      0.37       319
#            comp.graphics       0.48      0.53      0.50       389
#  comp.os.ms-windows.misc       0.37      0.29      0.32       394
# comp.sys.ibm.pc.hardware       0.46      0.39      0.42       392
#    comp.sys.mac.hardware       0.51      0.48      0.49       385
#           comp.windows.x       0.54      0.50      0.52       395
#             misc.forsale       0.56      0.62      0.59       390
#                rec.autos       0.54      0.49      0.51       396
#          rec.motorcycles       0.28      0.53      0.37       398
#       rec.sport.baseball       0.68      0.67      0.67       397
#         rec.sport.hockey       0.62      0.70      0.66       399
#                sci.crypt       0.53      0.51      0.52       396
#          sci.electronics       0.50      0.41      0.45       393
#                  sci.med       0.61      0.70      0.65       396
#                sci.space       0.60      0.59      0.59       394
#   soc.religion.christian       0.54      0.67      0.60       398
#       talk.politics.guns       0.39      0.38      0.39       364
#    talk.politics.mideast       0.63      0.59      0.61       376
#       talk.politics.misc       0.44      0.35      0.39       310
#       talk.religion.misc       0.29      0.13      0.18       251
#
#              avg / total       0.50      0.50      0.50      7532
#
# Time after stemming: 4.135200000000054
#
# Most frequent words deleted - 30000
# Least frequent words deleted - 30000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.43      0.29      0.34       319
#            comp.graphics       0.47      0.45      0.46       389
#  comp.os.ms-windows.misc       0.35      0.22      0.27       394
# comp.sys.ibm.pc.hardware       0.36      0.42      0.39       392
#    comp.sys.mac.hardware       0.44      0.32      0.37       385
#           comp.windows.x       0.46      0.50      0.48       395
#             misc.forsale       0.51      0.58      0.54       390
#                rec.autos       0.49      0.43      0.46       396
#          rec.motorcycles       0.54      0.39      0.45       398
#       rec.sport.baseball       0.31      0.69      0.43       397
#         rec.sport.hockey       0.65      0.62      0.64       399
#                sci.crypt       0.50      0.53      0.51       396
#          sci.electronics       0.40      0.38      0.39       393
#                  sci.med       0.59      0.67      0.63       396
#                sci.space       0.62      0.55      0.58       394
#   soc.religion.christian       0.51      0.65      0.57       398
#       talk.politics.guns       0.42      0.37      0.39       364
#    talk.politics.mideast       0.60      0.58      0.59       376
#       talk.politics.misc       0.35      0.34      0.35       310
#       talk.religion.misc       0.26      0.11      0.16       251
#
#              avg / total       0.47      0.46      0.46      7532
# Time after stemming: 4.776740000000018
#
# Most frequent words deleted - 40000
# Least frequent words deleted - 40000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.43      0.29      0.34       319
#            comp.graphics       0.41      0.46      0.43       389
#  comp.os.ms-windows.misc       0.32      0.25      0.28       394
# comp.sys.ibm.pc.hardware       0.37      0.34      0.35       392
#    comp.sys.mac.hardware       0.38      0.31      0.34       385
#           comp.windows.x       0.51      0.48      0.49       395
#             misc.forsale       0.49      0.61      0.55       390
#                rec.autos       0.46      0.43      0.44       396
#          rec.motorcycles       0.53      0.37      0.43       398
#       rec.sport.baseball       0.28      0.69      0.40       397
#         rec.sport.hockey       0.64      0.60      0.62       399
#                sci.crypt       0.50      0.50      0.50       396
#          sci.electronics       0.40      0.38      0.39       393
#                  sci.med       0.59      0.65      0.62       396
#                sci.space       0.62      0.55      0.58       394
#   soc.religion.christian       0.51      0.60      0.55       398
#       talk.politics.guns       0.40      0.32      0.36       364
#    talk.politics.mideast       0.63      0.56      0.59       376
#       talk.politics.misc       0.36      0.34      0.35       310
#       talk.religion.misc       0.20      0.10      0.13       251
#
#              avg / total       0.46      0.45      0.45      7532
#
# Time after stemming: 4.740274999999997

# %% [markdown]
# ## 4. Классификация после лемматизации

# %%
twenty_train.data = lemmatization_train_texts.copy()
twenty_test.data = lemmatization_test_texts.copy()

# %%
for el in deletions:
    print("Most frequent words deleted -", el[0])
    print("Least frequent words deleted -", el[1])
    update_forbidden_words(forbiddenWords, el[0], el[1])
    print("RESULTS:")
    deleteWordsStats(twenty_train, twenty_test, forbiddenWords)
    print("Time after lemmatization:", countTime(twenty_train, twenty_test, 1))
    print()
# Out:
# Most frequent words deleted - 0
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.56      0.48      0.52       319
#            comp.graphics       0.70      0.71      0.71       389
#  comp.os.ms-windows.misc       0.66      0.54      0.59       394
# comp.sys.ibm.pc.hardware       0.64      0.67      0.66       392
#    comp.sys.mac.hardware       0.76      0.69      0.72       385
#           comp.windows.x       0.79      0.74      0.77       395
#             misc.forsale       0.50      0.84      0.63       390
#                rec.autos       0.80      0.69      0.74       396
#          rec.motorcycles       0.76      0.76      0.76       398
#       rec.sport.baseball       0.83      0.82      0.82       397
#         rec.sport.hockey       0.87      0.90      0.88       399
#                sci.crypt       0.85      0.71      0.77       396
#          sci.electronics       0.56      0.61      0.58       393
#                  sci.med       0.79      0.79      0.79       396
#                sci.space       0.76      0.72      0.74       394
#   soc.religion.christian       0.65      0.81      0.72       398
#       talk.politics.guns       0.58      0.68      0.63       364
#    talk.politics.mideast       0.81      0.78      0.80       376
#       talk.politics.misc       0.58      0.47      0.52       310
#       talk.religion.misc       0.44      0.27      0.33       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time after lemmatization: 4.211116000000175
#
# Most frequent words deleted - 0
# Least frequent words deleted - 10000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.57      0.47      0.51       319
#            comp.graphics       0.70      0.70      0.70       389
#  comp.os.ms-windows.misc       0.61      0.62      0.61       394
# comp.sys.ibm.pc.hardware       0.72      0.62      0.67       392
#    comp.sys.mac.hardware       0.73      0.71      0.72       385
#           comp.windows.x       0.79      0.74      0.77       395
#             misc.forsale       0.76      0.80      0.78       390
#                rec.autos       0.76      0.71      0.74       396
#          rec.motorcycles       0.78      0.75      0.77       398
#       rec.sport.baseball       0.56      0.86      0.68       397
#         rec.sport.hockey       0.89      0.89      0.89       399
#                sci.crypt       0.81      0.74      0.77       396
#          sci.electronics       0.59      0.57      0.58       393
#                  sci.med       0.79      0.78      0.79       396
#                sci.space       0.74      0.73      0.74       394
#   soc.religion.christian       0.65      0.82      0.73       398
#       talk.politics.guns       0.57      0.68      0.62       364
#    talk.politics.mideast       0.69      0.81      0.75       376
#       talk.politics.misc       0.60      0.44      0.51       310
#       talk.religion.misc       0.55      0.21      0.30       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time after lemmatization: 4.301625000000058
#
# Most frequent words deleted - 0
# Least frequent words deleted - 25000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.58      0.47      0.52       319
#            comp.graphics       0.67      0.72      0.70       389
#  comp.os.ms-windows.misc       0.64      0.56      0.60       394
# comp.sys.ibm.pc.hardware       0.72      0.62      0.67       392
#    comp.sys.mac.hardware       0.71      0.73      0.72       385
#           comp.windows.x       0.81      0.74      0.77       395
#             misc.forsale       0.76      0.79      0.78       390
#                rec.autos       0.78      0.70      0.74       396
#          rec.motorcycles       0.79      0.76      0.77       398
#       rec.sport.baseball       0.56      0.86      0.68       397
#         rec.sport.hockey       0.85      0.91      0.88       399
#                sci.crypt       0.82      0.72      0.77       396
#          sci.electronics       0.59      0.56      0.58       393
#                  sci.med       0.76      0.78      0.77       396
#                sci.space       0.72      0.75      0.74       394
#   soc.religion.christian       0.65      0.82      0.73       398
#       talk.politics.guns       0.56      0.70      0.62       364
#    talk.politics.mideast       0.80      0.77      0.78       376
#       talk.politics.misc       0.55      0.45      0.49       310
#       talk.religion.misc       0.45      0.24      0.31       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time after lemmatization: 4.5099850000001425
#
# Most frequent words deleted - 0
# Least frequent words deleted - 40000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.50      0.50      0.50       319
#            comp.graphics       0.68      0.71      0.70       389
#  comp.os.ms-windows.misc       0.59      0.61      0.60       394
# comp.sys.ibm.pc.hardware       0.68      0.65      0.67       392
#    comp.sys.mac.hardware       0.77      0.69      0.73       385
#           comp.windows.x       0.84      0.71      0.77       395
#             misc.forsale       0.75      0.81      0.78       390
#                rec.autos       0.77      0.71      0.74       396
#          rec.motorcycles       0.76      0.76      0.76       398
#       rec.sport.baseball       0.55      0.86      0.67       397
#         rec.sport.hockey       0.84      0.90      0.87       399
#                sci.crypt       0.79      0.74      0.76       396
#          sci.electronics       0.59      0.55      0.57       393
#                  sci.med       0.79      0.79      0.79       396
#                sci.space       0.74      0.74      0.74       394
#   soc.religion.christian       0.65      0.81      0.72       398
#       talk.politics.guns       0.59      0.66      0.63       364
#    talk.politics.mideast       0.84      0.76      0.79       376
#       talk.politics.misc       0.58      0.45      0.51       310
#       talk.religion.misc       0.53      0.22      0.31       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time after lemmatization: 4.986493999999993
#
# Most frequent words deleted - 0
# Least frequent words deleted - 55000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.54      0.49      0.51       319
#            comp.graphics       0.68      0.72      0.70       389
#  comp.os.ms-windows.misc       0.62      0.57      0.59       394
# comp.sys.ibm.pc.hardware       0.67      0.65      0.66       392
#    comp.sys.mac.hardware       0.76      0.70      0.73       385
#           comp.windows.x       0.77      0.73      0.75       395
#             misc.forsale       0.73      0.81      0.77       390
#                rec.autos       0.75      0.71      0.73       396
#          rec.motorcycles       0.78      0.74      0.76       398
#       rec.sport.baseball       0.87      0.78      0.82       397
#         rec.sport.hockey       0.57      0.93      0.71       399
#                sci.crypt       0.83      0.73      0.77       396
#          sci.electronics       0.63      0.55      0.59       393
#                  sci.med       0.74      0.79      0.77       396
#                sci.space       0.74      0.74      0.74       394
#   soc.religion.christian       0.61      0.82      0.70       398
#       talk.politics.guns       0.58      0.66      0.62       364
#    talk.politics.mideast       0.81      0.76      0.78       376
#       talk.politics.misc       0.59      0.47      0.52       310
#       talk.religion.misc       0.49      0.21      0.30       251
#
#              avg / total       0.70      0.69      0.69      7532
#
# Time after lemmatization: 4.732161000000133
#
# Most frequent words deleted - 0
# Least frequent words deleted - 70000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.53      0.49      0.51       319
#            comp.graphics       0.69      0.71      0.70       389
#  comp.os.ms-windows.misc       0.61      0.58      0.59       394
# comp.sys.ibm.pc.hardware       0.68      0.66      0.67       392
#    comp.sys.mac.hardware       0.71      0.70      0.71       385
#           comp.windows.x       0.82      0.72      0.77       395
#             misc.forsale       0.75      0.80      0.78       390
#                rec.autos       0.76      0.70      0.73       396
#          rec.motorcycles       0.80      0.73      0.76       398
#       rec.sport.baseball       0.55      0.83      0.67       397
#         rec.sport.hockey       0.85      0.91      0.88       399
#                sci.crypt       0.87      0.69      0.77       396
#          sci.electronics       0.59      0.56      0.58       393
#                  sci.med       0.73      0.81      0.77       396
#                sci.space       0.70      0.77      0.73       394
#   soc.religion.christian       0.68      0.80      0.73       398
#       talk.politics.guns       0.56      0.70      0.62       364
#    talk.politics.mideast       0.83      0.75      0.79       376
#       talk.politics.misc       0.59      0.46      0.52       310
#       talk.religion.misc       0.45      0.22      0.29       251
#
#              avg / total       0.69      0.69      0.69      7532
# Time after lemmatization: 4.533349999999928
#
# Most frequent words deleted - 0
# Least frequent words deleted - 85000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.45      0.50      0.48       319
#            comp.graphics       0.71      0.68      0.69       389
#  comp.os.ms-windows.misc       0.60      0.57      0.58       394
# comp.sys.ibm.pc.hardware       0.70      0.60      0.65       392
#    comp.sys.mac.hardware       0.73      0.71      0.72       385
#           comp.windows.x       0.78      0.74      0.76       395
#             misc.forsale       0.76      0.79      0.78       390
#                rec.autos       0.72      0.70      0.71       396
#          rec.motorcycles       0.75      0.72      0.74       398
#       rec.sport.baseball       0.53      0.81      0.64       397
#         rec.sport.hockey       0.82      0.89      0.85       399
#                sci.crypt       0.83      0.71      0.77       396
#          sci.electronics       0.59      0.55      0.57       393
#                  sci.med       0.76      0.78      0.77       396
#                sci.space       0.70      0.73      0.71       394
#   soc.religion.christian       0.67      0.79      0.72       398
#       talk.politics.guns       0.57      0.69      0.62       364
#    talk.politics.mideast       0.77      0.74      0.76       376
#       talk.politics.misc       0.57      0.43      0.49       310
#       talk.religion.misc       0.46      0.22      0.30       251
#
#              avg / total       0.68      0.68      0.68      7532
#
# Time after lemmatization: 5.319205000000011
#
# Most frequent words deleted - 0
# Least frequent words deleted - 90000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.53      0.42      0.47       319
#            comp.graphics       0.67      0.66      0.66       389
#  comp.os.ms-windows.misc       0.61      0.58      0.59       394
# comp.sys.ibm.pc.hardware       0.66      0.60      0.63       392
#    comp.sys.mac.hardware       0.69      0.67      0.68       385
#           comp.windows.x       0.79      0.71      0.75       395
#             misc.forsale       0.67      0.80      0.73       390
#                rec.autos       0.74      0.64      0.69       396
#          rec.motorcycles       0.79      0.70      0.74       398
#       rec.sport.baseball       0.51      0.80      0.62       397
#         rec.sport.hockey       0.81      0.89      0.85       399
#                sci.crypt       0.82      0.69      0.75       396
#          sci.electronics       0.55      0.54      0.54       393
#                  sci.med       0.71      0.77      0.74       396
#                sci.space       0.72      0.72      0.72       394
#   soc.religion.christian       0.63      0.80      0.70       398
#       talk.politics.guns       0.56      0.65      0.60       364
#    talk.politics.mideast       0.71      0.77      0.74       376
#       talk.politics.misc       0.56      0.39      0.46       310
#       talk.religion.misc       0.47      0.23      0.31       251
#
#              avg / total       0.67      0.67      0.66      7532
#
# Time after lemmatization: 4.83304800000019
#
# Most frequent words deleted - 10000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.45      0.37      0.40       319
#            comp.graphics       0.18      0.56      0.27       389
#  comp.os.ms-windows.misc       0.44      0.31      0.36       394
# comp.sys.ibm.pc.hardware       0.50      0.43      0.47       392
#    comp.sys.mac.hardware       0.56      0.43      0.49       385
#           comp.windows.x       0.67      0.53      0.59       395
#             misc.forsale       0.51      0.45      0.48       390
#                rec.autos       0.55      0.52      0.53       396
#          rec.motorcycles       0.54      0.43      0.48       398
#       rec.sport.baseball       0.70      0.65      0.67       397
#         rec.sport.hockey       0.71      0.67      0.69       399
#                sci.crypt       0.44      0.41      0.42       396
#          sci.electronics       0.41      0.32      0.36       393
#                  sci.med       0.58      0.57      0.58       396
#                sci.space       0.55      0.48      0.51       394
#   soc.religion.christian       0.50      0.60      0.54       398
#       talk.politics.guns       0.40      0.40      0.40       364
#    talk.politics.mideast       0.59      0.59      0.59       376
#       talk.politics.misc       0.41      0.30      0.35       310
#       talk.religion.misc       0.31      0.24      0.27       251
#
#              avg / total       0.51      0.47      0.48      7532
#
# Time after lemmatization: 4.48446899999999
#
# Most frequent words deleted - 25000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.26      0.15      0.19       319
#            comp.graphics       0.50      0.29      0.36       389
#  comp.os.ms-windows.misc       0.34      0.16      0.21       394
# comp.sys.ibm.pc.hardware       0.42      0.26      0.32       392
#    comp.sys.mac.hardware       0.39      0.23      0.29       385
#           comp.windows.x       0.60      0.36      0.45       395
#             misc.forsale       0.49      0.33      0.39       390
#                rec.autos       0.42      0.31      0.36       396
#          rec.motorcycles       0.44      0.27      0.33       398
#       rec.sport.baseball       0.56      0.37      0.45       397
#         rec.sport.hockey       0.61      0.45      0.52       399
#                sci.crypt       0.37      0.25      0.30       396
#          sci.electronics       0.36      0.19      0.25       393
#                  sci.med       0.46      0.44      0.45       396
#                sci.space       0.41      0.33      0.37       394
#   soc.religion.christian       0.46      0.45      0.45       398
#       talk.politics.guns       0.08      0.54      0.13       364
#    talk.politics.mideast       0.47      0.45      0.46       376
#       talk.politics.misc       0.32      0.19      0.24       310
#       talk.religion.misc       0.24      0.16      0.19       251
#
#              avg / total       0.42      0.31      0.34      7532
#
# Time after lemmatization: 4.5620910000000094
#
# Most frequent words deleted - 40000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.25      0.14      0.18       319
#            comp.graphics       0.43      0.19      0.26       389
#  comp.os.ms-windows.misc       0.22      0.09      0.13       394
# comp.sys.ibm.pc.hardware       0.07      0.65      0.13       392
#    comp.sys.mac.hardware       0.37      0.17      0.23       385
#           comp.windows.x       0.55      0.29      0.38       395
#             misc.forsale       0.49      0.23      0.32       390
#                rec.autos       0.43      0.19      0.27       396
#          rec.motorcycles       0.42      0.19      0.26       398
#       rec.sport.baseball       0.51      0.24      0.33       397
#         rec.sport.hockey       0.61      0.30      0.40       399
#                sci.crypt       0.26      0.16      0.20       396
#          sci.electronics       0.32      0.11      0.17       393
#                  sci.med       0.42      0.32      0.36       396
#                sci.space       0.35      0.23      0.28       394
#   soc.religion.christian       0.43      0.34      0.38       398
#       talk.politics.guns       0.25      0.15      0.19       364
#    talk.politics.mideast       0.43      0.32      0.37       376
#       talk.politics.misc       0.23      0.10      0.14       310
#       talk.religion.misc       0.22      0.13      0.17       251
#
#              avg / total       0.37      0.23      0.26      7532
#
# Time after lemmatization: 4.497513000000026
#
# Most frequent words deleted - 55000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.26      0.12      0.16       319
#            comp.graphics       0.07      0.79      0.13       389
#  comp.os.ms-windows.misc       0.23      0.07      0.11       394
# comp.sys.ibm.pc.hardware       0.32      0.10      0.16       392
#    comp.sys.mac.hardware       0.31      0.13      0.19       385
#           comp.windows.x       0.52      0.22      0.31       395
#             misc.forsale       0.42      0.17      0.24       390
#                rec.autos       0.41      0.14      0.21       396
#          rec.motorcycles       0.33      0.11      0.17       398
#       rec.sport.baseball       0.45      0.18      0.26       397
#         rec.sport.hockey       0.56      0.24      0.33       399
#                sci.crypt       0.24      0.12      0.16       396
#          sci.electronics       0.33      0.10      0.16       393
#                  sci.med       0.41      0.27      0.33       396
#                sci.space       0.35      0.21      0.26       394
#   soc.religion.christian       0.37      0.27      0.31       398
#       talk.politics.guns       0.28      0.14      0.18       364
#    talk.politics.mideast       0.46      0.30      0.36       376
#       talk.politics.misc       0.25      0.08      0.13       310
#       talk.religion.misc       0.21      0.10      0.13       251
#
#              avg / total       0.34      0.20      0.22      7532
# Time after lemmatization: 4.470242999999982
#
# Most frequent words deleted - 70000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.21      0.08      0.11       319
#            comp.graphics       0.46      0.13      0.20       389
#  comp.os.ms-windows.misc       0.24      0.06      0.09       394
# comp.sys.ibm.pc.hardware       0.32      0.07      0.12       392
#    comp.sys.mac.hardware       0.26      0.09      0.14       385
#           comp.windows.x       0.49      0.15      0.23       395
#             misc.forsale       0.36      0.12      0.18       390
#                rec.autos       0.38      0.12      0.18       396
#          rec.motorcycles       0.28      0.07      0.12       398
#       rec.sport.baseball       0.46      0.14      0.21       397
#         rec.sport.hockey       0.60      0.21      0.31       399
#                sci.crypt       0.28      0.10      0.15       396
#          sci.electronics       0.06      0.74      0.11       393
#                  sci.med       0.34      0.19      0.24       396
#                sci.space       0.33      0.16      0.21       394
#   soc.religion.christian       0.41      0.26      0.32       398
#       talk.politics.guns       0.26      0.10      0.15       364
#    talk.politics.mideast       0.45      0.28      0.35       376
#       talk.politics.misc       0.23      0.06      0.09       310
#       talk.religion.misc       0.17      0.08      0.11       251
#
#              avg / total       0.34      0.16      0.18      7532
#
# Time after lemmatization: 4.393674000000146
#
# Most frequent words deleted - 85000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.22      0.08      0.11       319
#            comp.graphics       0.54      0.10      0.17       389
#  comp.os.ms-windows.misc       0.20      0.04      0.07       394
# comp.sys.ibm.pc.hardware       0.06      0.82      0.11       392
#    comp.sys.mac.hardware       0.35      0.03      0.06       385
#           comp.windows.x       0.47      0.07      0.12       395
#             misc.forsale       0.34      0.08      0.13       390
#                rec.autos       0.42      0.08      0.14       396
#          rec.motorcycles       0.35      0.06      0.10       398
#       rec.sport.baseball       0.45      0.09      0.15       397
#         rec.sport.hockey       0.63      0.18      0.28       399
#                sci.crypt       0.29      0.08      0.12       396
#          sci.electronics       0.27      0.05      0.09       393
#                  sci.med       0.25      0.14      0.18       396
#                sci.space       0.29      0.12      0.17       394
#   soc.religion.christian       0.40      0.19      0.26       398
#       talk.politics.guns       0.22      0.07      0.11       364
#    talk.politics.mideast       0.48      0.26      0.34       376
#       talk.politics.misc       0.22      0.05      0.07       310
#       talk.religion.misc       0.08      0.03      0.04       251
#
#              avg / total       0.33      0.13      0.14      7532
#
# Time after lemmatization: 4.723848000000089
#
# Most frequent words deleted - 90000
# Least frequent words deleted - 0
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.20      0.06      0.09       319
#            comp.graphics       0.46      0.06      0.11       389
#  comp.os.ms-windows.misc       0.16      0.02      0.04       394
# comp.sys.ibm.pc.hardware       0.26      0.02      0.04       392
#    comp.sys.mac.hardware       0.13      0.03      0.05       385
#           comp.windows.x       0.49      0.05      0.09       395
#             misc.forsale       0.25      0.04      0.07       390
#                rec.autos       0.38      0.06      0.10       396
#          rec.motorcycles       0.38      0.05      0.08       398
#       rec.sport.baseball       0.41      0.06      0.10       397
#         rec.sport.hockey       0.53      0.10      0.16       399
#                sci.crypt       0.27      0.06      0.09       396
#          sci.electronics       0.23      0.02      0.04       393
#                  sci.med       0.05      0.82      0.10       396
#                sci.space       0.25      0.08      0.12       394
#   soc.religion.christian       0.39      0.15      0.21       398
#       talk.politics.guns       0.17      0.04      0.07       364
#    talk.politics.mideast       0.54      0.22      0.31       376
#       talk.politics.misc       0.18      0.03      0.05       310
#       talk.religion.misc       0.11      0.03      0.05       251
#
#              avg / total       0.30      0.10      0.10      7532
#
# Time after lemmatization: 4.459941000000072
#
# Most frequent words deleted - 10000
# Least frequent words deleted - 10000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.43      0.36      0.39       319
#            comp.graphics       0.56      0.43      0.48       389
#  comp.os.ms-windows.misc       0.44      0.31      0.37       394
# comp.sys.ibm.pc.hardware       0.50      0.42      0.46       392
#    comp.sys.mac.hardware       0.57      0.45      0.50       385
#           comp.windows.x       0.66      0.51      0.57       395
#             misc.forsale       0.52      0.45      0.48       390
#                rec.autos       0.54      0.51      0.52       396
#          rec.motorcycles       0.18      0.58      0.27       398
#       rec.sport.baseball       0.70      0.65      0.68       397
#         rec.sport.hockey       0.71      0.67      0.69       399
#                sci.crypt       0.43      0.41      0.42       396
#          sci.electronics       0.43      0.32      0.36       393
#                  sci.med       0.56      0.58      0.57       396
#                sci.space       0.54      0.48      0.51       394
#   soc.religion.christian       0.51      0.58      0.54       398
#       talk.politics.guns       0.40      0.39      0.40       364
#    talk.politics.mideast       0.59      0.60      0.59       376
#       talk.politics.misc       0.40      0.29      0.34       310
#       talk.religion.misc       0.27      0.20      0.23       251
#
#              avg / total       0.50      0.47      0.48      7532
#
# Time after lemmatization: 4.462624999999889
#
# Most frequent words deleted - 20000
# Least frequent words deleted - 20000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.32      0.19      0.24       319
#            comp.graphics       0.10      0.62      0.18       389
#  comp.os.ms-windows.misc       0.39      0.20      0.26       394
# comp.sys.ibm.pc.hardware       0.43      0.26      0.33       392
#    comp.sys.mac.hardware       0.48      0.28      0.35       385
#           comp.windows.x       0.61      0.40      0.48       395
#             misc.forsale       0.45      0.34      0.39       390
#                rec.autos       0.47      0.36      0.40       396
#          rec.motorcycles       0.49      0.32      0.39       398
#       rec.sport.baseball       0.63      0.45      0.52       397
#         rec.sport.hockey       0.64      0.51      0.57       399
#                sci.crypt       0.41      0.30      0.35       396
#          sci.electronics       0.41      0.24      0.30       393
#                  sci.med       0.49      0.48      0.49       396
#                sci.space       0.45      0.39      0.42       394
#   soc.religion.christian       0.45      0.43      0.44       398
#       talk.politics.guns       0.27      0.23      0.25       364
#    talk.politics.mideast       0.49      0.50      0.49       376
#       talk.politics.misc       0.31      0.20      0.24       310
#       talk.religion.misc       0.23      0.14      0.17       251
#
#              avg / total       0.43      0.35      0.37      7532
#
# Time after lemmatization: 4.272326999999905
#
# Most frequent words deleted - 30000
# Least frequent words deleted - 30000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.26      0.15      0.19       319
#            comp.graphics       0.44      0.20      0.28       389
#  comp.os.ms-windows.misc       0.23      0.09      0.13       394
# comp.sys.ibm.pc.hardware       0.08      0.71      0.14       392
#    comp.sys.mac.hardware       0.42      0.15      0.22       385
#           comp.windows.x       0.57      0.28      0.37       395
#             misc.forsale       0.47      0.26      0.34       390
#                rec.autos       0.36      0.19      0.25       396
#          rec.motorcycles       0.43      0.20      0.27       398
#       rec.sport.baseball       0.59      0.28      0.38       397
#         rec.sport.hockey       0.54      0.32      0.40       399
#                sci.crypt       0.32      0.18      0.23       396
#          sci.electronics       0.35      0.16      0.22       393
#                  sci.med       0.49      0.37      0.42       396
#                sci.space       0.42      0.23      0.30       394
#   soc.religion.christian       0.47      0.34      0.40       398
#       talk.politics.guns       0.21      0.13      0.16       364
#    talk.politics.mideast       0.43      0.37      0.40       376
#       talk.politics.misc       0.25      0.13      0.17       310
#       talk.religion.misc       0.17      0.09      0.12       251
#
#              avg / total       0.38      0.25      0.27      7532
# Time after lemmatization: 4.305761000000075
#
# Most frequent words deleted - 40000
# Least frequent words deleted - 40000
# RESULTS:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.24      0.09      0.14       319
#            comp.graphics       0.06      0.77      0.11       389
#  comp.os.ms-windows.misc       0.13      0.04      0.06       394
# comp.sys.ibm.pc.hardware       0.29      0.08      0.12       392
#    comp.sys.mac.hardware       0.42      0.08      0.13       385
#           comp.windows.x       0.41      0.20      0.27       395
#             misc.forsale       0.43      0.14      0.21       390
#                rec.autos       0.31      0.09      0.14       396
#          rec.motorcycles       0.42      0.11      0.18       398
#       rec.sport.baseball       0.57      0.16      0.25       397
#         rec.sport.hockey       0.50      0.19      0.27       399
#                sci.crypt       0.27      0.11      0.15       396
#          sci.electronics       0.27      0.06      0.10       393
#                  sci.med       0.45      0.22      0.30       396
#                sci.space       0.33      0.13      0.19       394
#   soc.religion.christian       0.44      0.23      0.30       398
#       talk.politics.guns       0.20      0.07      0.11       364
#    talk.politics.mideast       0.43      0.26      0.32       376
#       talk.politics.misc       0.24      0.07      0.11       310
#       talk.religion.misc       0.18      0.08      0.11       251
#
#              avg / total       0.34      0.16      0.18      7532
#
# Time after lemmatization: 4.325761999999941

# %% [markdown]
# #### Вывод:
# 1)Без предобработки:
# Как мы видим удаление редко встречающихся не влияет на результат классификации, вплоть до удаления 90% слов
# В то время, как удаления только 10% самых встречающихся слов уменьшает точность классификации на 20%, удаление большего числа слов очень сильно уменьшает характеристику recall, precision же уменьшается заметно медленее
#
#
# 2)После стемминга:
# Как и в случае без предобработки, удаление редко встречающихся слов не меняет точность классификации. Удаление же часто встречающихся слов уменьшает точность классификации не так сильно, как в случае без предобработки, при этом recall и precision уменьшаются одинаково. При удалении 90% слов точность классификации понижается c 0.7 до 0.45
#
# 3)После лемматизации:
# Почти точно также как и без предобработки

# %% [markdown]
# ## 4. Удаление стоп-слов

# %%
twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
sw_eng = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /home/pavel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def deleteStopWords(twenty_train, twenty_test):
    original_train_texts = twenty_train.data.copy()
    original_test_texts = twenty_test.data.copy()
    twenty_train.data = [' '.join([word for word in text.split() if not word in sw_eng]) for text in twenty_train.data]
    twenty_test.data = [' '.join([word for word in text.split() if not word in sw_eng]) for text in twenty_test.data]
    TfIdf(twenty_train, twenty_test)
    print("Time:", countTime(twenty_train, twenty_test, 5))
    twenty_train.data = original_train_texts.copy()
    twenty_test.data = original_test_texts.copy()

# %%
deleteStopWords(twenty_train, twenty_test)
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.51      0.46      0.49       319
#            comp.graphics       0.68      0.72      0.70       389
#  comp.os.ms-windows.misc       0.64      0.61      0.63       394
# comp.sys.ibm.pc.hardware       0.66      0.67      0.66       392
#    comp.sys.mac.hardware       0.76      0.71      0.74       385
#           comp.windows.x       0.79      0.72      0.75       395
#             misc.forsale       0.74      0.80      0.77       390
#                rec.autos       0.81      0.71      0.76       396
#          rec.motorcycles       0.79      0.76      0.77       398
#       rec.sport.baseball       0.55      0.84      0.67       397
#         rec.sport.hockey       0.83      0.89      0.86       399
#                sci.crypt       0.85      0.70      0.77       396
#          sci.electronics       0.65      0.56      0.60       393
#                  sci.med       0.77      0.79      0.78       396
#                sci.space       0.74      0.76      0.75       394
#   soc.religion.christian       0.62      0.81      0.70       398
#       talk.politics.guns       0.58      0.68      0.63       364
#    talk.politics.mideast       0.83      0.77      0.80       376
#       talk.politics.misc       0.57      0.46      0.51       310
#       talk.religion.misc       0.49      0.24      0.32       251
#
#              avg / total       0.70      0.70      0.69      7532
#
# Time: 4.31075920000003

# %% [markdown]
# #### Анализ:
# Как мы видим, удаление стоп-слов не меняет точность классификации

# %% [markdown]
# # Дополнительное задание

# %%
twenty_train.data = original_train_texts.copy()
twenty_test.data = original_test_texts.copy()

# %% [markdown]
# ## Закон Ципфа

# %%
def hyp(x):
    return 300000/x

import pylab as plt
nums = range(len(sortedWords))
sortedFreq = [pair[1] for pair in sortedWordCount]
plt.plot(nums[10:500], sortedFreq[10:500])
x = np.linspace(13, 500)
y = hyp(x)
plt.plot(x, y)

# %% [markdown]
# ## Закон Хипса

# %%
def getUniqueWordsNum(train, sz):
    texts = train.data.copy()
    uniqueWords = set()
    uniqueWordsNum = [0]*sz
    wordsNum = 0
    for i in range(len(texts)):
        if wordsNum < sz - 1:
            for word in texts[i].split():
                if wordsNum < sz - 1:
                    wordsNum += 1
                    uniqueWords.add(word)
                    uniqueWordsNum[wordsNum] = len(uniqueWords)
    return uniqueWordsNum
                    

sz = 2000000
uniqueWordsNum = getUniqueWordsNum(twenty_train, sz)
nums = range(sz)
plt.plot(nums, uniqueWordsNum)
x = np.linspace(0, sz)
y = 15*x**(0.6)
plt.plot(x, y)

# %% [markdown]
# ### Как мы видим, оба закона выполнены
